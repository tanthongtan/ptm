# %% [markdown]
# <a href="https://colab.research.google.com/github/tanthongtan/ptm/blob/master/sam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hyperparameters

# %%
num_topic = 50
dataset = 'kos'
method = 'sam'

#model hyperparameters
alpha_scalar = 50./num_topic
c0 = 1000.0
kappa1 = 10000.0

#GMC hyperparameters
num_samples = 1
num_burn = 5000
S = 25000
L = 20
eta_theta = 4e-2
rho_theta = 1e-1
eta_mu = 4e-4
rho_mu = 1e-1

# %% [markdown]
# # Run GMC Inference

# %%
#only for google colab
import sys
import os
if 'google.colab' in sys.modules:
    #lets see what gpu we were given
    # !nvidia-smi
    #get repository
    # !git clone https://github.com/tanthongtan/ptm.git
    # %cd '/content/ptm'
    #get ref corp if doesn't exist
    if not os.path.isdir('wiki_final'):
        # !unzip -q "/content/drive/My Drive/wiki_final.zip"

import torch
import torch.nn.functional as F
from geodesic import GeodesicMonteCarlo
from dataset import load_data, csr_to_torchsparse
import geodesic as g
import distributions as D
from tqdm.notebook import tqdm
import torch.distributions as dist
import numpy as np
from utils import print_topics, get_topics, vmf_perplexity, clustering_metrics_20news, print_summary

#make all tensors cuda if available and double
if torch.cuda.is_available():
    torch.set_default_tensor_type(torch.cuda.FloatTensor)
    gpu = True
else:
    torch.set_default_tensor_type(torch.FloatTensor)
    gpu = False

#Load Data
data_tr, data_te, vocab, vocab_size, num_tr = load_data(use_tfidf = True, sublinear = False, normalize = True, dataset = dataset)    
tensor_te = csr_to_torchsparse(data_te, gpu)

#declare tensor hyperparameters
alpha = torch.full((1,num_topic), alpha_scalar)
mu0 = F.normalize(torch.full((vocab_size,),-1.0),dim=-1)

#randomly initialize model parameters
theta = torch.randn(num_tr,num_topic-1)
mu = F.normalize(torch.randn(num_topic, vocab_size) / (vocab_size ** 0.5) + mu0, p=2, dim=-1)

#declare GMC transition kernels
kernel = GeodesicMonteCarlo(L)
params = {'theta': theta, 'mu':mu}
init_etas = {'theta': eta_theta, 'mu':eta_mu}
geodesics = {'theta': g.RnGeodesic(eta = eta_theta, rho = rho_theta), 'mu': g.SphericalGeodesic(eta = eta_mu, rho = rho_mu)}
vs = {name: geodesics[name].projection(params[name],dist.MultivariateNormal(torch.zeros(params[name].shape[-1]), torch.eye(params[name].shape[-1])).sample([params[name].shape[0]])) for name in params}

#start sampling loop
t = tqdm(range(num_samples+num_burn))
theta_samples = 0
mu_samples = 0
for i in t:
    idx = torch.randperm(num_tr)[:S]
    x_batch = csr_to_torchsparse(data_tr[idx.cpu()], gpu)
    theta = params['theta']
    params['theta'] = theta[idx]
    v_theta = vs['theta']
    vs['theta'] = v_theta[idx]

    for name in geodesics:
        geodesics[name].eta = init_etas[name] * ((i+1) ** (-1./5.))
    params, vs = kernel.stochastic_transition(params, vs, geodesics, D.SamJointDistributionWithStickDir(x_batch, alpha, c0, mu0, kappa1))
    
    theta[idx] = params['theta']
    v_theta[idx] = vs['theta']
    params['theta'] = theta
    vs['theta'] = v_theta
    
    theta = params['theta']
    mu = params['mu']

    if torch.any(mu != mu):        
        break    
   
    if i >= num_burn:
        theta_samples += theta
        mu_samples += mu

    if i % 100 == 0:
        print("\ncurrent iteration:", i)         
        print("mu norms", mu.norm(dim=-1).sum(), num_topic)        
        print("sparsity",(torch.abs(mu)**2.).norm(dim=-1))
        print("sparsitymean",(torch.abs(mu)**2.).norm(dim=-1).mean())
        pi = dist.StickBreakingTransform()(theta)
        print("pi sums", pi.sum(dim=-1).sum(), num_tr)         
        
        sum_ll = 0.0
        sum_cs = 0.0
        for j in range(int(np.ceil(num_tr/S))):
            curr_pi = pi[j*S:j*S+S]
            curr_tensor_tr = csr_to_torchsparse(data_tr[j*S:j*S+S], gpu)
            curr_avg = F.normalize(torch.matmul(curr_pi,mu), p=2, dim=-1)
            sum_ll += D.log_prob_von_mises_fisher(kappa1 * curr_avg, curr_tensor_tr).sum()
            sum_cs += D.sparse_dense_dot(curr_tensor_tr, curr_avg).sum()

        print("log likelihood", sum_ll / num_tr)        
        print("cosine similarity", sum_cs / num_tr)
        print("perplexity", vmf_perplexity(tensor_te, mu, kappa1, alpha, N=1000),"\n")
                
    if i % 1000 == 0:
        emb = mu.cpu().numpy()
        print_topics(get_topics(emb,vocab))
        print("")
# Out:
# Sun Oct  4 10:46:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Cloning into 'ptm'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 340 (delta 30), reused 34 (delta 10), pack-reused 276
# Receiving objects: 100% (340/340), 257.46 MiB | 25.81 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# /content/ptm
# Dim Training Data (2916, 6906)
# Dim Test Data (514, 6906)
# HBox(children=(FloatProgress(value=0.0, max=5001.0), HTML(value='')))
# current iteration: 0
# mu norms tensor(50.) 50
# sparsity tensor([0.0413, 0.1120, 0.0445, 0.0320, 0.0814, 0.3311, 0.0458, 0.0364, 0.1070,
#         0.0591, 0.0551, 0.0452, 0.0607, 0.0738, 0.0807, 0.0666, 0.0662, 0.0845,
#         0.0906, 0.0930, 0.0847, 0.0990, 0.1007, 0.1053, 0.1057, 0.1104, 0.1011,
#         0.0976, 0.1006, 0.1028, 0.0937, 0.0993, 0.1006, 0.0873, 0.0914, 0.0856,
#         0.0867, 0.0820, 0.0789, 0.0715, 0.0632, 0.0626, 0.0523, 0.0482, 0.0441,
#         0.0400, 0.0338, 0.0296, 0.0290, 0.0254])
# sparsitymean tensor(0.0784)
# pi sums tensor(2916.) 2916
# log likelihood tensor(18123.4531)
# cosine similarity tensor(0.2080)
# perplexity tensor(-18006.6777)
#
# bush iraq people time president war party states campaign democratic
# november kerry poll bush senate polls house account electoral governor
# bush kerry iraq campaign republican bushs administration party president security
# poll november war kerry iraq vote dean percent american senate
# november bush kerry poll polls iraq account campaign electoral media
# november account electoral governor house voting republicans vote senate sunzoo
# bush kerry poll president dean voters polls john republican democratic
# bush kerry november iraq administration house republicans percent democrats vote
# november bush kerry republicans account poll house electoral governor voting
# dean kerry edwards bush clark lieberman gephardt democratic poll state
# bush kerry percent president poll delay administration iraq people voters
# kerry poll dean edwards bush primary senate state democratic percent
# kerry bush dean edwards democratic poll campaign house people war
# kerry bush dean poll iraq democratic state campaign senate edwards
# bush kerry dean poll november iraq house campaign democratic state
# bush kerry dean poll clark edwards democratic november primary campaign
# bush administration bushs president george florida texas white disapprove reelection
# states races house candidates united white mrliberal president ads country
# knowles murkowski miller tony susa republican draft bunning health lisa
# oct gotv general sinclair youre report bunning people air explosives
# vote bill votes voting ohio president kerrys server senate time
# convention speech boston aug jul obama republican bounce night bloggers
# court salazar law supreme colorado coors election texas rights clinton
# republicans democrats south janklow gop republican seat daschle dakota bill
# iraq war troops bushs weapons blair intelligence president saddam powell
# news media fox sinclair journalists press coverage cbs keyes bloggers
#
#
# current iteration: 3100
# mu norms tensor(49.9991) 50
# sparsity tensor([0.1398, 0.1206, 0.1495, 0.0986, 0.1033, 0.3497, 0.2624, 0.2508, 0.3142,
#         0.6535, 0.4243, 0.3560, 0.5195, 0.6465, 0.3191, 0.2444, 0.2048, 0.2811,
#         0.1511, 0.5706, 0.0929, 0.5192, 0.7561, 0.4102, 0.2840, 0.3648, 0.6265,
#         0.1083, 0.0638, 0.2279, 0.3851, 0.1169, 0.4399, 0.2473, 0.4258, 0.1690,
#         0.1830, 0.1529, 0.1202, 0.3944, 0.6188, 0.1927, 0.1519, 0.1226, 0.2860,
#         0.2973, 0.1705, 0.0971, 0.4342, 0.2672])
# sparsitymean tensor(0.2977)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.2559)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18622.2910)
#
#
# current iteration: 3200
# mu norms tensor(49.9990) 50
# sparsity tensor([0.1390, 0.1174, 0.1478, 0.1003, 0.1042, 0.3525, 0.2643, 0.2479, 0.3127,
#         0.6491, 0.4226, 0.3543, 0.5060, 0.6481, 0.3254, 0.2529, 0.2094, 0.2818,
#         0.1562, 0.5795, 0.0933, 0.5196, 0.7562, 0.4098, 0.2842, 0.3717, 0.6193,
#         0.1072, 0.0651, 0.2265, 0.3803, 0.1189, 0.4300, 0.2477, 0.4267, 0.1671,
#         0.1819, 0.1521, 0.1175, 0.3967, 0.6206, 0.1899, 0.1502, 0.1204, 0.2920,
#         0.2933, 0.1683, 0.0957, 0.4364, 0.2636])
# sparsitymean tensor(0.2975)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.2148)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18620.6133)
#
#
# current iteration: 3300
# mu norms tensor(49.9989) 50
# sparsity tensor([0.1398, 0.1208, 0.1538, 0.0966, 0.1030, 0.3567, 0.2659, 0.2505, 0.3182,
#         0.6542, 0.4241, 0.3533, 0.5067, 0.6499, 0.3183, 0.2434, 0.2094, 0.2847,
#         0.1531, 0.5731, 0.0952, 0.5225, 0.7554, 0.4052, 0.2882, 0.3775, 0.6192,
#         0.1098, 0.0633, 0.2267, 0.3801, 0.1276, 0.4357, 0.2473, 0.4297, 0.1726,
#         0.1822, 0.1521, 0.1185, 0.3961, 0.6201, 0.1898, 0.1549, 0.1223, 0.2946,
#         0.2857, 0.1728, 0.0931, 0.4341, 0.2641])
# sparsitymean tensor(0.2982)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20291.8223)
# cosine similarity tensor(0.4248)
# perplexity tensor(-

# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.0703)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18623.8184)
#
#
# current iteration: 3900
# mu norms tensor(49.9979) 50
# sparsity tensor([0.1373, 0.1185, 0.1489, 0.1022, 0.1046, 0.3551, 0.2634, 0.2516, 0.3196,
#         0.6569, 0.4220, 0.3528, 0.5161, 0.6444, 0.3171, 0.2397, 0.2053, 0.2785,
#         0.1538, 0.5725, 0.0944, 0.5205, 0.7578, 0.4137, 0.2892, 0.3829, 0.6141,
#         0.1109, 0.0653, 0.2298, 0.3864, 0.1279, 0.4291, 0.2397, 0.4299, 0.1727,
#         0.1829, 0.1509, 0.1134, 0.3936, 0.6200, 0.1795, 0.1574, 0.1260, 0.2933,
#         0.2887, 0.1708, 0.0938, 0.4388, 0.2630])
# sparsitymean tensor(0.2979)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.2637)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18624.2930)
#
#
# current iteration: 4000
# mu norms tensor(49.9977) 50
# sparsity tensor([0.1390, 0.1179, 0.1526, 0.1050, 0.1052, 0.3538, 0.2618, 0.2507, 0.3157,
#         0.6589, 0.4245, 0.3523, 0.5168, 0.6471, 0.3202, 0.2525, 0.2037, 0.2740,
#         0.1540, 0.5691, 0.0891, 0.5180, 0.7547, 0.4004, 0.2844, 0.3743, 0.6154,
#         0.1112, 0.0653, 0.2246, 0.3850, 0.1303, 0.4384, 0.2435, 0.4223, 0.1658,
#         0.1842, 0.1536, 0.1184, 0.3935, 0.6204, 0.1818, 0.1599, 0.1193, 0.2845,
#         0.2900, 0.1729, 0.0957, 0.4308, 0.2685])
# sparsitymean tensor(0.2974)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.1621)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18618.3398)
#
# iraqi baghdad iraq fallujah forces iraqis killed shiite city attacks
# november turnout parecommend duderino trouble ground exit zogby idetestthispres hotshotxi
# administration intelligence commission white officials report cia house clarke documents
# states bin laden united america terrorism terrorists saddam osama air
# sunday john sens edition adviser sun cbs cnn fox powell
# november voting account electoral governor sunzoo house senate polls christopher
# marriage gay amendment rights issue republicans ban hate samesex law
# district race seat schrader house republican gop elections democrat alexander
# jobs job growth economy report economic employment labor numbers workers
# dean clark deans howard iowa jan support trippi primary money
# delay ethics committee house morrison texas delays majority investigation leader
# carson coburn oklahoma brad oksen coburns senate tulsa sep dozen
# million money raised fundraising dnc ads cash spent total hand
# kerry john kerrys bush general veterans results leads boat trend
# state ohio florida powell keyes governor secretary states colin county
# iowa schaller tom caucus jan primary democratic results gephardt ill
# donors dkos matsunaka dozen jim farmer nag knowles morrison murphy
# herseth diedrich house chandler daschle dakota thune elections south sdal
# military guard service records draft national texas duty vietnam war
# cheney president vice dick cheneys halliburton saddam oil mccain defense
# server database sep susa traffic online florida servers ads trend
# nader ballot signatures naders ralph petition arizona oregon petitions undecided
# percent voters poll knowles rating gore murkowski favorable margin romero
# debate bunning candidates mongiardo debates oct senator spin won server
# clark lieberman kucinich gephardt sharpton braun primary results democratic parenthesis
# poll polls gallup polling numbers tracking latest undecided lead results
# edwards feb gephardt kerry wins veep primary jul people delegates
# america conservative radio film air media liberal movie book political
# ill blog community ive internet bloggers online blogs politics mrliberal
# tax billion budget cuts deficit taxes spending income federal health
# meteor blades time primary presidential primaries poll democratic john keyes
# reagan science research cell reagans space stem scientists jun melanie
# party democratic dnc republican democrats republicans donors candidates national meetup
# senate keyes obama illinois elections salazar ryan colorado ilsen race
# campaign ads internet political kerrys media campaigns manager negative running
# voters election florida polling gotv registered registration voter states voting
# abu ghraib rumsfeld military prisoners abuse prison torture abuses defense
# gephardt endorsement unions union endorsements iowa afscme endorsed seiu labor
# people clinton war americans time country women terrorism american life
# specter toomey hoeffel results pdf specters toomeys surveyusa pennsylvania apr
# bush administration bushs president george florida white texas reelection guard
# states house races candidates white mrliberal united president seats country
# knowles murkowski miller tony susa republican bunning draft health race
# oct gotv general sinclair bunning youre people report explosives air
# vote bill voting votes ohio president time kerrys white senate
# convention speech boston republican aug jul bounce republicans time bloggers
# court salazar law supreme colorado coors texas rights election knowles
# republicans democrats south janklow gop republican dakota seat daschle bill
# iraq war troops bushs blair weapons president intelligence powell saddam
# news media fox sinclair journalists press cbs coverage network keyes
#
#
# current iteration: 4100
# mu norms tensor(49.9974) 50
# sparsity tensor([0.1384, 0.1190, 0.1486, 0.1042, 0.1059, 0.3534, 0.2579, 0.2506, 0.3146,
#         0.6536, 0.4233, 0.3507, 0.5115, 0.6497, 0.3249, 0.2514, 0.2054, 0.2769,
#         0.1552, 0.5683, 0.0905, 0.5200, 0.7523, 0.4113, 0.2849, 0.3724, 0.6191,
#         0.1111, 0.0639, 0.2259, 0.3859, 0.1307, 0.4393, 0.2438, 0.4220, 0.1685,
#         0.1829, 0.1545, 0.1188, 0.3935, 0.6231, 0.1788, 0.1598, 0.1207, 0.2944,
#         0.2966, 0.1684, 0.0916, 0.4379, 0.2689])
# sparsitymean tensor(0.2979)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.0742)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18622.5898)
#
#
# current iteration: 4200
# mu norms tensor(49.9972) 50
# sparsity tensor([0.1391, 0.1208, 0.1497, 0.1049, 0.1037, 0.3528, 0.2617, 0.2461, 0.3195,
#         0.6565, 0.4227, 0.3501, 0.5204, 0.6459, 0.3206, 0.2537, 0.2043, 0.2728,
#         0.1557, 0.5657, 0.0883, 0.5211, 0.7553, 0.4065, 0.2877, 0.3733, 0.6165,
#         0.1085, 0.0663, 0.2263, 0.3831, 0.1320, 0.4450, 0.2417, 0.4231, 0.1716,
#         0.1830, 0.1558, 0.1220, 0.3973, 0.6203, 0.1793, 0.1604, 0.1225, 0.2813,
#         0.2930, 0.1680, 0.0960, 0.4354, 0.2655])
# sparsitymean tensor(0.2979)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.0508)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18624.3320)
#
#
# current iteration: 4300
# mu norms tensor(49.9969) 50
# sparsity tensor([0.1386, 0.1188, 0.1485, 0.1040, 0.1059, 0.3514, 0.2625, 0.2527, 0.3173,
#         0.6622, 0.4255, 0.3536, 0.5158, 0.6474, 0.3246, 0.2531, 0.2062, 0.2751,
#         0.1537, 0.5735, 0.0886, 0.5196, 0.7580, 0.4093, 0.2876, 0.3740, 0.6179,
#         0.1111, 0.0679, 0.2242, 0.3829, 0.1302, 0.4392, 0.2516, 0.4238, 0.1710,
#         0.1856, 0.1508, 0.1191, 0.3952, 0.6215, 0.1784, 0.1688, 0.1251, 0.2911,
#         0.2846, 0.1684, 0.0918, 0.4377, 0.2666])
# sparsitymean tensor(0.2986)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.0684)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18636.8105)
#
#
# current iteration: 4400
# mu norms tensor(49.9966) 50
# sparsity tensor([0.1412, 0.1192, 0.1540, 0.1019, 0.1057, 0.3514, 0.2615, 0.2540, 0.3121,
#         0.6569, 0.4221, 0.3542, 0.5149, 0.6500, 0.3226, 0.2463, 0.2075, 0.2748,
#         0.1557, 0.5672, 0.0901, 0.5213, 0.7596, 0.4084, 0.2825, 0.3661, 0.6290,
#         0.1103, 0.0664, 0.2294, 0.3805, 0.1327, 0.4355, 0.2503, 0.4221, 0.1693,
#         0.1849, 0.1566, 0.1177, 0.3992, 0.6221, 0.1791, 0.1633, 0.1312, 0.2930,
#         0.2931, 0.1697, 0.0937, 0.4294, 0.2677])
# sparsitymean tensor(0.2985)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20291.8867)
# cosine similarity tensor(0.4248)
# perplexity tensor(-18613.5449)
#
#
# current iteration: 4500
# mu norms tensor(49.9962) 50
# sparsity tensor([0.1409, 0.1206, 0.1512, 0.1045, 0.1040, 0.3521, 0.2573, 0.2472, 0.3201,
#         0.6573, 0.4223, 0.3547, 0.5117, 0.6427, 0.3245, 0.2467, 0.2033, 0.2824,
#         0.1535, 0.5731, 0.0909, 0.5229, 0.7548, 0.3941, 0.2844, 0.3732, 0.6181,
#         0.1106, 0.0664, 0.2237, 0.3856, 0.1331, 0.4402, 0.2471, 0.4191, 0.1720,
#         0.1844, 0.1539, 0.1152, 0.3938, 0.6227, 0.1780, 0.1654, 0.1270, 0.2882,
#         0.2959, 0.1694, 0.0898, 0.4308, 0.2660])
# sparsitymean tensor(0.2977)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.2031)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18613.8535)
#
#
# current iteration: 4600
# mu norms tensor(49.9959) 50
# sparsity tensor([0.1399, 0.1184, 0.1543, 0.1081, 0.1041, 0.3541, 0.2603, 0.2530, 0.3154,
#         0.6583, 0.4255, 0.3556, 0.5153, 0.6474, 0.3204, 0.2471, 0.2083, 0.2731,
#         0.1538, 0.5704, 0.0921, 0.5215, 0.7556, 0.4044, 0.2801, 0.3752, 0.6170,
#         0.1142, 0.0644, 0.2306, 0.3840, 0.1325, 0.4367, 0.2503, 0.4262, 0.1748,
#         0.1839, 0.1533, 0.1127, 0.3922, 0.6246, 0.1762, 0.1595, 0.1257, 0.2972,
#         0.2954, 0.1708, 0.0945, 0.4352, 0.2735])
# sparsitymean tensor(0.2988)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.1777)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18617.2969)
#
#
# current iteration: 4700
# mu norms tensor(49.9955) 50
# sparsity tensor([0.1388, 0.1188, 0.1555, 0.1048, 0.1022, 0.3567, 0.2661, 0.2506, 0.3145,
#         0.6540, 0.4279, 0.3495, 0.5051, 0.6444, 0.3263, 0.2438, 0.2029, 0.2728,
#         0.1561, 0.5692, 0.0904, 0.5177, 0.7554, 0.4045, 0.2838, 0.3739, 0.6142,
#         0.1143, 0.0659, 0.2263, 0.3839, 0.1314, 0.4351, 0.2536, 0.4340, 0.1700,
#         0.1809, 0.1542, 0.1109, 0.3911, 0.6161, 0.1753, 0.1665, 0.1290, 0.2872,
#         0.2929, 0.1738, 0.0931, 0.4316, 0.2691])
# sparsitymean tensor(0.2977)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20291.8770)
# cosine similarity tensor(0.4248)
# perplexity tensor(-18619.5801)
#
#
# current iteration: 4800
# mu norms tensor(49.9950) 50
# sparsity tensor([0.1389, 0.1166, 0.1504, 0.1070, 0.1036, 0.3539, 0.2633, 0.2532, 0.3136,
#         0.6551, 0.4199, 0.3515, 0.5132, 0.6424, 0.3241, 0.2525, 0.2037, 0.2798,
#         0.1535, 0.5703, 0.0872, 0.5264, 0.7517, 0.3991, 0.2828, 0.3743, 0.6162,
#         0.1123, 0.0663, 0.2257, 0.3883, 0.1298, 0.4416, 0.2595, 0.4211, 0.1754,
#         0.1838, 0.1505, 0.1142, 0.3992, 0.6209, 0.1734, 0.1665, 0.1308, 0.2836,
#         0.2873, 0.1694, 0.0955, 0.4383, 0.2772])
# sparsitymean tensor(0.2983)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20291.7617)
# cosine similarity tensor(0.4248)
# perplexity tensor(-18626.6348)
#
#
# current iteration: 4900
# mu norms tensor(49.9945) 50
# sparsity tensor([0.1388, 0.1185, 0.1540, 0.1107, 0.1034, 0.3555, 0.2634, 0.2504, 0.3148,
#         0.6544, 0.4255, 0.3493, 0.5087, 0.6491, 0.3294, 0.2505, 0.2031, 0.2796,
#         0.1562, 0.5691, 0.0863, 0.5187, 0.7603, 0.4004, 0.2813, 0.3710, 0.6224,
#         0.1128, 0.0659, 0.2260, 0.3828, 0.1325, 0.4415, 0.2509, 0.4242, 0.1716,
#         0.1820, 0.1517, 0.1147, 0.3983, 0.6157, 0.1765, 0.1650, 0.1297, 0.2866,
#         0.2878, 0.1713, 0.0930, 0.4352, 0.2686])
# sparsitymean tensor(0.2982)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20291.8164)
# cosine similarity tensor(0.4248)
# perplexity tensor(-18619.8203)
#
#
# current iteration: 5000
# mu norms tensor(49.9940) 50
# sparsity tensor([0.1382, 0.1197, 0.1528, 0.1163, 0.1051, 0.3505, 0.2658, 0.2588, 0.3120,
#         0.6589, 0.4210, 0.3508, 0.5083, 0.6433, 0.3254, 0.2424, 0.2067, 0.2767,
#         0.1548, 0.5670, 0.0878, 0.5172, 0.7600, 0.4035, 0.2912, 0.3707, 0.6223,
#         0.1088, 0.0663, 0.2277, 0.3864, 0.1364, 0.4334, 0.2492, 0.4232, 0.1732,
#         0.1838, 0.1538, 0.1126, 0.3961, 0.6187, 0.1727, 0.1610, 0.1291, 0.2925,
#         0.2882, 0.1709, 0.0935, 0.4413, 0.2678])
# sparsitymean tensor(0.2983)
# pi sums tensor(2916.) 2916
# log likelihood tensor(20292.0234)
# cosine similarity tensor(0.4249)
# perplexity tensor(-18607.5312)
#
# iraqi baghdad fallujah iraq forces killed iraqis shiite city troops
# november turnout duderino parecommend trouble ground exit zogby con west
# administration intelligence commission officials white report cia attacks clarke house
# states bin united laden america air space saddam terrorists south
# sunday john sens edition adviser sun cbs cnn powell fox
# november voting account electoral governor sunzoo house polls senate liberalrakkasan
# marriage gay amendment rights republicans issue ban hate samesex unions
# district race seat schrader house gop alexander elections democrat republican
# jobs job growth economy report economic employment labor workers numbers
# dean clark deans howard iowa jan trippi support kerry primary
# delay ethics committee house morrison texas delays majority investigation leader
# carson coburn oklahoma brad oksen coburns tulsa senate humphreys dozen
# million money raised dnc fundraising cash ads spent total cycle
# kerry john kerrys bush general veterans boat results arg undecided
# state ohio florida powell keyes governor secretary county colin office
# iowa schaller tom caucus jan primary democratic results ill moines
# donors dkos matsunaka farmer dozen nag jim knowles morrison candidates
# herseth diedrich house chandler dakota daschle thune elections south sdal
# military guard service records draft national texas duty vietnam bushs
# cheney president vice dick cheneys halliburton saddam oil mccain company
# server susa ads database traffic sep online servers florida trend
# nader ballot signatures naders ralph petition arizona oregon jun undecided
# percent voters knowles poll rating murkowski gore margin favorable survey
# debate bunning mongiardo candidates debates senator spin oct won race
# clark lieberman kucinich sharpton gephardt braun primary results democratic latest
# poll polls gallup polling numbers tracking lead latest undecided trend
# edwards feb gephardt kerry veep wins jul primary delegates ticket
# america air conservative radio film media book liberal movie political
# ill blog community internet online blogs bloggers ive server page
# tax billion budget cuts deficit taxes spending income federal health
# blades meteor primary time presidential poll primaries john democratic feb
# reagan research science cell reagans space stem american jun scientists
# party democratic republican dnc democrats republicans donors candidates meetup national
# senate keyes obama illinois elections salazar ryan race colorado coors
# campaign ads internet political kerrys media manager campaigns bushcheney running
# voters election florida polling registered voter registration gotv county states
# abu ghraib rumsfeld military prisoners abuse prison torture abuses defense
# gephardt endorsement unions union endorsements iowa endorsed afscme seiu candidates
# people clinton war americans country women time terrorism american men
# specter toomey hoeffel results pdf surveyusa specters toomeys senate pennsylvania
# bush administration bushs president george florida white texas approve disapprove
# states house races candidates white mrliberal president seats united country
# knowles murkowski miller tony republican susa bunning lisa health draft
# oct gotv general sinclair bunning people youre report air explosives
# vote bill votes voting ohio president server kerrys white senate
# convention speech boston republican jul aug bounce republicans night obama
# court law salazar supreme colorado coors texas election rights janklow
# republicans democrats south janklow gop republican daschle seat bill dakota
# iraq war troops bushs blair weapons intelligence president saddam powell
# news media fox sinclair journalists coverage press cbs network broadcast

# %% [markdown]
# # Get Topic Coherence

# %%
mu_final = mu_samples / num_samples
theta_final = theta_samples / num_samples
print("final perplexity", vmf_perplexity(tensor_te, mu_final, kappa1, alpha, N=1000))
emb = mu_final.cpu().numpy()
topics = get_topics(emb, vocab)
print_summary(topics,method,dataset)

if dataset == '20news':
    pi = dist.StickBreakingTransform()(theta_final)
    pi = pi.cpu().numpy()
    clustering_metrics_20news(pi)
# Out:
# final perplexity tensor(-18619.0996)
#
# Method  = sam
# Number of topics = 50
# Dataset = kos
#
#  NPMI       TU         Topic
#  0.17908    0.90000    iraqi baghdad fallujah iraq forces killed iraqis shiite city troops
# -0.00857    0.95000    november turnout duderino parecommend trouble ground exit zogby con west
#  0.05006    0.67500    administration intelligence commission officials white report cia attacks clarke house
#  0.06646    0.58333    states bin united laden america air space saddam terrorists south
#  0.04781    0.76667    sunday john sens edition adviser sun cbs cnn powell fox
#  0.02665    0.63667    november voting account electoral governor sunzoo house polls senate liberalrakkasan
#  0.09055    0.82500    marriage gay amendment rights republicans issue ban hate samesex unions
