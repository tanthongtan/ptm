# %% [markdown]
# <a href="https://colab.research.google.com/github/tanthongtan/ptm/blob/master/vptm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hyperparameters

# %%
num_topic = 50
dataset = 'nips'
method = 'vptm'

#vptm hyperparameters
alpha_scalar = 50./num_topic
v= 0.01
c = 0.005
prior_mu = 'neg' #possible options: neg, pos, mean
 
#GMC hyperparameters
num_samples = 1
num_burn = 5000
S = 25000
L = 20
eta_theta = 1e-1
rho_theta = 1e-1
eta_mu = 5e-4
rho_mu = 1e-1
eta_kappa = 5e-1
rho_kappa = 1e-1

# %% [markdown]
# # Run GMC Inference

# %%
#only for google colab
import sys
import os
if 'google.colab' in sys.modules:
    #lets see what gpu we were given
    # !nvidia-smi
    #get repository
    # !git clone https://github.com/tanthongtan/ptm.git
    # %cd '/content/ptm'
    #get ref corp if doesn't exist
    if not os.path.isdir('wiki_final'):
        # !unzip -q "/content/drive/My Drive/wiki_final.zip"
 
import torch
import torch.nn.functional as F
from geodesic import GeodesicMonteCarlo
from dataset import load_data, csr_to_torchsparse
import geodesic as g
import distributions as D
from tqdm.notebook import tqdm
import torch.distributions as dist
import numpy as np
from utils import print_topics, get_topics, vmf_perplexity, clustering_metrics_20news, print_summary
 
#make all tensors cuda if available and double
if torch.cuda.is_available():
    torch.set_default_tensor_type(torch.cuda.FloatTensor)
    gpu = True
else:
    torch.set_default_tensor_type(torch.DoubleTensor)
    gpu = False
 
#Load Data
data_tr, data_te, vocab, vocab_size, num_tr = load_data(use_tfidf = True, sublinear = False, normalize = True, dataset = dataset)    
tensor_te = csr_to_torchsparse(data_te, gpu)
tensor_tr = csr_to_torchsparse(data_tr, gpu)

#declare tensor hyperparameters
alpha = torch.full((1,num_topic), alpha_scalar)
if prior_mu == 'neg':
    mu0 = F.normalize(torch.full((vocab_size,),-1.0),dim=-1)
if prior_mu == 'pos':
    mu0 = F.normalize(torch.full((vocab_size,),1.0),dim=-1)
if prior_mu == 'mean':
    mu0 = F.normalize(torch.sparse.sum(tensor_tr,dim=0).to_dense(),dim=-1)
 
#randomly initialize model parameters
theta = torch.randn(num_tr,num_topic-1)
mu = F.normalize(torch.randn(num_topic, vocab_size) / (vocab_size ** 0.5) + mu0, p=2, dim=-1)
kappa = torch.randn(num_topic,1)*50 + 50. * (vocab_size ** 0.5) 
 
#declare GMC transition kernels
kernel = GeodesicMonteCarlo(L)
params = {'theta': theta, 'mu':mu, 'kappa': kappa}
init_etas = {'theta': eta_theta, 'mu':eta_mu, 'kappa': eta_kappa}
geodesics = {'theta': g.RnGeodesic(eta = eta_theta, rho = rho_theta), 'mu': g.SphericalGeodesic(eta = eta_mu, rho = rho_mu), 'kappa': g.PositiveGeodesic(eta = eta_kappa, rho = rho_kappa)}
vs = {name: geodesics[name].projection(params[name],dist.MultivariateNormal(torch.zeros(params[name].shape[-1]), torch.eye(params[name].shape[-1])).sample([params[name].shape[0]])) for name in params}
 
#start sampling loop
t = tqdm(range(num_samples+num_burn))
theta_samples = 0
mu_samples = 0
kappa_samples = 0
for i in t:
    
    idx = torch.randperm(num_tr)[:S]
    x_batch = csr_to_torchsparse(data_tr[idx.cpu()], gpu)
    theta = params['theta']
    params['theta'] = theta[idx]
    v_theta = vs['theta']
    vs['theta'] = v_theta[idx]
 
    for name in geodesics:
        geodesics[name].eta = init_etas[name] * ((i+1) ** (-1./5.))
    params, vs = kernel.stochastic_transition(params, vs, geodesics, D.VptmJointDistributionWithStickDirConjugatePrior(x_batch, alpha, c, mu0, v))
    
    theta[idx] = params['theta']
    v_theta[idx] = vs['theta']
    params['theta'] = theta
    vs['theta'] = v_theta
    
    theta = params['theta']
    kappa = params['kappa']
    mu = params['mu']
    
    if torch.any(kappa != kappa):
        break
   
    if i >= num_burn:
        theta_samples += theta
        mu_samples += mu
        kappa_samples += kappa

    if i % 100 == 0:
        print("\ncurrent iteration:", i)
        print("kappa mean",kappa.mean())
        print("kappas",kappa)
        pi = dist.StickBreakingTransform()(theta)
        print("mu norms", mu.norm(dim=-1).sum(), num_topic)
        print("sparsity",(torch.abs(mu)**2.).norm(dim=-1))
        print("sparsitymean",(torch.abs(mu)**2.).norm(dim=-1).mean())
        print("pi sums", pi.sum(dim=-1).sum(), num_tr)

        sum_ll = 0.0
        sum_cs = 0.0
        for j in range(int(np.ceil(num_tr/S))):
            curr_pi = pi[j*S:j*S+S]
            curr_tensor_tr = csr_to_torchsparse(data_tr[j*S:j*S+S], gpu)
            curr_avg = torch.matmul(curr_pi,kappa*mu)
            sum_ll += D.log_prob_von_mises_fisher(curr_avg, curr_tensor_tr).sum()
            curr_avg = F.normalize(curr_avg,dim=-1)
            sum_cs += D.sparse_dense_dot(curr_tensor_tr, curr_avg).sum()
        
        print("log likelihood", sum_ll / num_tr)        
        print("cosine similarity", sum_cs / num_tr)
        print("perplexity", vmf_perplexity(tensor_te, mu, kappa, alpha, N=1000))

        sum_cs_spread = 0
        count_cs = 0
        for j in range(num_topic-1):
            for k in range(j+1,num_topic):
                sum_cs_spread += (mu[j] * mu[k]).sum(dim=-1)
                count_cs += 1
        print("mean cs spread", sum_cs_spread / count_cs,"\n")
        
    if i % 1000 == 0:
        emb = mu.cpu().numpy()
        print_topics(get_topics(emb,vocab))
        print("")
# Out:
# Fri Dec  4 09:16:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    27W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Cloning into 'ptm'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 351 (delta 34), reused 38 (delta 12), pack-reused 276
# Receiving objects: 100% (351/351), 257.53 MiB | 18.88 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# /content/ptm
# Dim Training Data (4934, 11463)
# Dim Test Data (870, 11463)
# HBox(children=(FloatProgress(value=0.0, max=5001.0), HTML(value='')))
# current iteration: 0
# kappa mean tensor(5172.3379)
# kappas tensor([[5083.4648],
#         [5119.6885],
#         [5017.8979],
#         [5009.2305],
#         [5119.1484],
#         [5061.9297],
#         [5106.7583],
#         [5270.1182],
#         [5100.1440],
#         [5122.5825],
#         [5028.4761],
#         [5111.4448],
#         [5136.0039],
#         [5128.9897],
#         [5065.4106],
#         [5229.4136],
#         [5189.0845],
#         [5225.4443],
#         [5139.1753],
#         [5151.6855],
#         [5183.7974],
#         [5111.7266],
#         [5113.9839],
#         [5139.1299],
#         [5101.2417],
#         [5145.9336],
#         [5209.9116],
#         [5141.1841],
#         [5234.7539],
#         [5195.6099],
#         [5229.4707],
#         [5139.3750],
#         [5161.4214],
#         [5270.7144],
#         [5187.8486],
#         [5162.5488],
#         [5210.6133],
#         [5242.1304],
#         [5191.7227],
#         [5233.1021],
#         [5257.4390],
#         [5191.1816],
#         [5266.6650],
#         [5155.2026],
#         [5227.0430],
#         [5331.0479],
#         [5360.7363],
#         [5242.6553],
#         [5281.7705],
#         [5280.8320]])
# mu norms tensor(50.) 50
# sparsity tensor([0.0474, 0.0422, 0.0484, 0.0434, 0.0404, 0.0452, 0.0452, 0.0434, 0.0369,
#         0.0432, 0.0368, 0.0365, 0.0359, 0.0370, 0.0364, 0.0351, 0.0332, 0.0344,
#         0.0345, 0.0357, 0.0352, 0.0297, 0.0338, 0.0333, 0.0328, 0.0316, 0.0325,
#         0.0318, 0.0315, 0.0324, 0.0279, 0.0303, 0.0299, 0.0292, 0.0255, 0.0258,
#         0.0248, 0.0248, 0.0227, 0.0233, 0.0221, 0.0219, 0.0197, 0.0202, 0.0184,
#         0.0178, 0.0171, 0.0171, 0.0169, 0.0169])
# sparsitymean tensor(0.0314)
# pi sums tensor(4934.) 4934
# log likelihood tensor(37692.7539)
# cosine similarity tensor(0.2579)
# perplexity tensor(-37726.9727)
# mean cs spread tensor(0.4448)
#
# model learning data algorithm training set network models function distribution
# data model learning algorithm set matrix function distribution training problem
# data learning model algorithm matrix set training network models kernel
# model data learning algorithm function set distribution network training models
# model data learning algorithm matrix function problem using set network
# learning model data training network algorithm function set networks time
# model learning data algorithm function set time policy matrix training
# learning data model algorithm set function training using kernel matrix
# model learning data algorithm network set training time using matrix
# learning algorithm data model function set kernel problem matrix training
# model data learning algorithm network set matrix time function training
# model learning data algorithm function set problem time network training
# data model learning algorithm network function time set using training
# learning model data network algorithm function set training time using
# model learning data network function time algorithm training set neural
# learning model data network training function algorithm set using matrix
# learning model data algorithm set image network function time policy
# learning model algorithm data set network training function time using
# model learning algorithm data network matrix time set problem function
# model learning algorithm data set time training function matrix network
# model learning data algorithm network function policy time set training
# model learning algorithm network data function image set matrix using
# model data learning algorithm function set matrix training distribution number
# model learning data algorithm training network set image function using
# learning model data network function time set algorithm training using
# model learning data algorithm function matrix set time training network
# learning model algorithm function data network time training image set
# learning data algorithm model time set function models matrix problem
# model data learning algorithm set using training network layer error
# learning model data algorithm set network error function time figure
# learning algorithm model data problem network time function training figure
# model data learning algorithm using set function training figure network
# model learning data network algorithm function training set models using
# learning data model function set network algorithm image time models
# learning model algorithm data network input figure set training matrix
# learning model function algorithm data using time matrix network problem
# model learning data algorithm matrix network distribution function neural problem
# model data algorithm function learning set training network networks number
# model algorithm data learning function set neural network matrix problem
# learning model network data algorithm training number function input set
# learning model data matrix algorithm set time using noise network
# model learning data algorithm network set used time training function
# learning model data network set algorithm algorithms function feature using
# learning model data algorithm figure distribution using set matrix function
# model figure learning data function set algorithm results vector network
# set model learning data function time network algorithm image networks
# algorithm model time training learning state node set linear class
# model algorithm using error network information learning first classification proposed
# data learning model time set used standard algorithm error discriminates
# learning data set algorithm neural training model time let step
#
#
# current iteration: 100
# kappa mean tensor(10520.6719)
# kappas tensor([[12500.4297],
#         [12692.4736],
#         [12637.0742],
#         [15403.6475],
#         [13391.7314],
#         [13833.3428],
#         [14785.4141],
#         [12868.4082],
#         [10431.1602],
#         [13631.5137],
#         [10445.0420],
#         [10240.5898],
#         [11215.5010],
#         [10381.6836],
#         [14090.4258],
#         [10794.5459],
#         [13070.9326],
#         [10027.3135],
#         [11470.4893],
#         [11739.9482],
#         [ 9605.0186],
#         [10789.9229],
#         [ 9727.3457],
#         [12721.9873],
#         [ 9271.5840],
#         [ 9787.7969],
#         [ 9168.3984],
#         [10366.6514],
#         [10673.7656],
#         [ 8958.3760],
#         [ 9363.9922],
#         [ 8966.1191],
#         [ 8200.1143],
#         [ 9115.0732],
#         [10056.9512],
#         [11593.7607],
#         [ 8530.4824],
#         [ 9103.2197],
#         [ 8424.4922],
#         [ 7805.6230],
#         [ 8734.2637],
#         [ 8876.2871],
#         [ 9498.2998],
#         [ 8037.2915],
#         [10635.2344],
#         [ 8460.3594],
#         [ 9139.1318],
#         [ 6807.0361],
#         [ 7545.9673],
#         [10417.4258]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3602, 0.3029, 0.4931, 0.1786, 0.6039, 0.2893, 0.5835, 0.1780, 0.4118,
#         0.1882, 0.2740, 0.1669, 0.4738, 0.3352, 0.4889, 0.3739, 0.5058, 0.3080,
#         0.4638, 0.4892, 0.2254, 0.6396, 0.3625, 0.4617, 0.1887, 0.3380, 0.4565,
#         0.3534, 0.2900, 0.5227, 0.4091, 0.2269, 0.5567, 0.2911, 0.6336, 0.1795,
#         0.1995, 0.2457, 0.1924, 0.2350, 0.2486, 0.3392, 0.5178, 0.2732, 0.3908,
#         0.3252, 0.3647, 0.0592, 0.6033, 0.2951])
# sparsitymean tensor(0.3579)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38858.9023)
# cosine similarity tensor(0.4723)
# perplexity tensor(-38051.2734)
# mean cs spread tensor(0.0760)
#
#
# current iteration: 200
# kappa mean tensor(12723.4502)
# kappas tensor([[14799.8398],
#         [14807.8359],
#         [14808.6445],
#         [18478.8203],
#         [15858.3945],
#         [15826.3438],
#         [17337.4707],
#         [15225.2500],
#         [12429.9717],
#         [16125.4902],
#         [12853.7051],
#         [12074.9990],
#         [13916.7412],
#         [12604.8076],
#         [16450.2324],
#         [12638.1357],
#         [15565.6123],
#         [11969.5762],
#         [13652.4209],
#         [14068.3086],
#         [11271.9121],
#         [13167.4121],
#         [11736.1797],
#         [14784.3076],
#         [11659.4727],
#         [11576.5527],
#         [11030.0010],
#         [12489.7910],
#         [12952.3027],
#         [10916.8867],
#         [12002.0947],
#         [10716.9258],
#         [ 9843.0537],
#         [11155.1182],
#         [12137.8320],
#         [14018.4082],
#         [10271.1982],
#         [11798.9453],
#         [10718.5645],
#         [10271.9727],
#         [11005.7666],
#         [11531.1270],
#         [11412.5439],
#         [ 9763.8105],
#         [12507.6357],
#         [11794.3418],
#         [10977.0000],
#         [ 8401.9561],
#         [10527.7637],
#         [12239.0332]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3732, 0.3135, 0.5062, 0.1845, 0.6207, 0.2969, 0.6280, 0.2029, 0.4154,
#         0.1972, 0.2676, 0.1739, 0.4717, 0.3526, 0.5652, 0.3722, 0.5218, 0.3192,
#         0.4785, 0.5046, 0.2339, 0.6512, 0.3905, 0.4755, 0.1913, 0.3501, 0.4828,
#         0.3580, 0.2936, 0.5301, 0.4178, 0.2123, 0.4597, 0.3184, 0.6494, 0.1871,
#         0.1857, 0.2651, 0.2005, 0.3476, 0.2563, 0.3362, 0.5430, 0.2640, 0.4106,
#         0.3199, 0.3982, 0.0715, 0.5007, 0.3010])
# sparsitymean tensor(0.3674)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38921.4023)
# cosine similarity tensor(0.4769)
# perplexity tensor(-38081.3867)
# mean cs spread tensor(0.0590)
#
#
# current iteration: 300
# kappa mean tensor(14129.6533)
# kappas tensor([[16280.4561],
#         [16164.8320],
#         [16188.6777],
#         [20336.2402],
#         [17470.0488],
#         [17024.5293],
#         [18910.4805],
#         [16654.2129],
#         [13761.9092],
#         [17673.0410],
#         [14384.1094],
#         [13301.3506],
#         [15581.6045],
#         [13918.7441],
#         [17875.4512],
#         [13888.6143],
#         [17090.6309],
#         [13222.6172],
#         [15053.1230],
#         [15508.5762],
#         [12346.1641],
#         [14646.3359],
#         [12953.7627],
#         [16107.1152],
#         [13152.6230],
#         [12766.5977],
#         [12236.0205],
#         [13810.2402],
#         [14422.3086],
#         [12221.0020],
#         [13571.7236],
#         [11890.0117],
#         [11289.4951],
#         [12450.7930],
#         [13433.1846],
#         [15559.5840],
#         [11452.1543],
#         [13450.5742],
#         [12174.8691],
#         [12016.4297],
#         [12484.3232],
#         [13049.9717],
#         [12564.4209],
#         [10937.3125],
#         [13657.6787],
#         [13859.1611],
#         [12118.9463],
#         [ 9732.3604],
#         [12542.4727],
#         [13295.8076]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3811, 0.3183, 0.5100, 0.1912, 0.6280, 0.3016, 0.6503, 0.2154, 0.4157,
#         0.1994, 0.2671, 0.1779, 0.4838, 0.3539, 0.5989, 0.3693, 0.5295, 0.3135,
#         0.4837, 0.5091, 0.2344, 0.6547, 0.4008, 0.4770, 0.1986, 0.3507, 0.4948,
#         0.3604, 0.2901, 0.5348, 0.4288, 0.2115, 0.3863, 0.3270, 0.6589, 0.1925,
#         0.1804, 0.2822, 0.2034, 0.3418, 0.2567, 0.3392, 0.5577, 0.2624, 0.4228,
#         0.3057, 0.4132, 0.0864, 0.5164, 0.3056])
# sparsitymean tensor(0.3715)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38950.4648)
# cosine similarity tensor(0.4792)
# perplexity tensor(-38097.0195)
# mean cs spread tensor(0.0512)
#
#
# current iteration: 400
# kappa mean tensor(15192.5244)
# kappas tensor([[17339.6719],
#         [17180.9922],
#         [17263.4102],
#         [21571.4570],
#         [18609.4531],
#         [17971.7480],
#         [20043.7754],
#         [17720.2285],
#         [14681.4814],
#         [18851.0957],
#         [15612.8301],
#         [14178.0215],
#         [16860.0176],
#         [14880.8789],
#         [18888.2207],
#         [14804.7900],
#         [18282.6113],
#         [14234.2910],
#         [16041.5869],
#         [16568.5898],
#         [13169.4287],
#         [15756.6582],
#         [13863.8535],
#         [17183.0273],
#         [14261.9131],
#         [13668.0146],
#         [13141.1104],
#         [14773.7666],
#         [15505.2900],
#         [13205.6768],
#         [14679.9404],
#         [12848.0713],
#         [13308.5234],
#         [13412.8525],
#         [14361.3867],
#         [16609.8652],
#         [12372.3975],
#         [14685.7529],
#         [13238.8613],
#         [13295.6641],
#         [13600.5215],
#         [14212.5479],
#         [13382.6143],
#         [11782.8301],
#         [14536.9951],
#         [15300.4043],
#         [13000.0830],
#         [10817.4893],
#         [13970.7119],
#         [14094.8350]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3836, 0.3220, 0.5144, 0.2054, 0.6312, 0.3102, 0.6630, 0.2219, 0.4181,
#         0.2022, 0.2726, 0.1782, 0.4953, 0.3532, 0.6124, 0.3678, 0.5404, 0.3075,
#         0.4859, 0.5133, 0.2368, 0.6635, 0.4061, 0.4809, 0.2017, 0.3514, 0.5080,
#         0.3614, 0.2898, 0.5392, 0.4300, 0.1914, 0.3935, 0.3313, 0.6657, 0.1949,
#         0.1783, 0.2864, 0.2048, 0.3337, 0.2534, 0.3417, 0.5582, 0.2586, 0.4271,
#         0.2950, 0.4232, 0.0816, 0.5220, 0.3071])
# sparsitymean tensor(0.3743)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38968.2930)
# cosine similarity tensor(0.4806)
# perplexity tensor(-38099.7852)
# mean cs spread tensor(0.0455)
#
#
# current iteration: 500
# kappa mean tensor(16036.5098)
# kappas tensor([[18131.9551],
#         [17997.4102],
#         [18112.8652],
#         [22381.1816],
#         [19524.9355],
#         [18676.3867],
#         [20929.5117],
#         [18569.1113],
#         [15461.0547],
#         [19811.9434],
#         [16562.6797],
#         [14889.7627],
#         [17829.7793],
#         [15669.9062],
#         [19755.7051],
#         [15516.3184],
#         [19186.2891],
#         [15021.3721],
#         [16888.4902],
#         [17422.4570],
#         [13794.7607],
#         [16608.4473],
#         [14574.8184],
#         [17980.5039],
#         [15221.5107],
#         [14369.7725],
#         [13892.1865],
#         [15503.2471],
#         [16377.6865],
#         [13981.8457],
#         [15525.6680],
#         [13592.5820],
#         [14965.5527],
#         [14189.0586],
#         [15122.0566],
#         [17455.7227],
#         [13113.8594],
#         [15694.7666],
#         [14093.2715],
#         [14293.8115],
#         [14502.3887],
#         [15145.3877],
#         [14089.0479],
#         [12464.6016],
#         [15241.2578],
#         [16457.5957],
#         [13682.3848],
#         [11706.7520],
#         [15126.6943],
#         [14719.1621]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3876, 0.3239, 0.5146, 0.2139, 0.6344, 0.3123, 0.6718, 0.2256, 0.4182,
#         0.2042, 0.2777, 0.1802, 0.4974, 0.3500, 0.6206, 0.3669, 0.5424, 0.3046,
#         0.4915, 0.5175, 0.2373, 0.6638, 0.4074, 0.4830, 0.2002, 0.3462, 0.5134,
#         0.3624, 0.2858, 0.5335, 0.4332, 0.1865, 0.3931, 0.3333, 0.6657, 0.1960,
#         0.1811, 0.2874, 0.2017, 0.3315, 0.2474, 0.3435, 0.5623, 0.2619, 0.4226,
#         0.2923, 0.4218, 0.0808, 0.5274, 0.3071])
# sparsitymean tensor(0.3753)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38980.4180)
# cosine similarity tensor(0.4814)
# perplexity tensor(-38107.5273)
# mean cs spread tensor(0.0412)
#
#
# current iteration: 600
# kappa mean tensor(16738.1289)
# kappas tensor([[18814.9434],
#         [18689.1504],
#         [18758.9492],
#         [23064.4316],
#         [20318.9180],
#         [19366.8223],
#         [21644.2871],
#         [19270.2285],
#         [16084.5547],
#         [20620.8008],
#         [17363.8848],
#         [15483.8301],
#         [18609.1230],
#         [16303.6221],
#         [20461.3301],
#         [16074.8789],
#         [19952.5645],
#         [15693.7080],
#         [17525.9453],
#         [18086.5430],
#         [14333.9395],
#         [17287.2871],
#         [15147.6592],
#         [18661.4160],
#         [16026.3926],
#         [14969.4766],
#         [14531.4492],
#         [16115.0049],
#         [17088.2871],
#         [14659.5459],
#         [16210.9658],
#         [14244.6670],
#         [16357.3262],
#         [14791.9883],
#         [15738.0566],
#         [18159.4336],
#         [13806.0439],
#         [16476.9121],
#         [14869.1523],
#         [15121.3877],
#         [15232.0557],
#         [15864.3086],
#         [14695.6846],
#         [13097.2168],
#         [15872.1885],
#         [17373.1328],
#         [14257.6689],
#         [12496.9951],
#         [16043.2197],
#         [15189.0752]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3888, 0.3266, 0.5195, 0.2201, 0.6355, 0.3124, 0.6806, 0.2287, 0.4232,
#         0.2064, 0.2904, 0.1808, 0.5058, 0.3468, 0.6256, 0.3673, 0.5452, 0.3034,
#         0.4903, 0.5217, 0.2393, 0.6684, 0.4092, 0.4824, 0.2016, 0.3461, 0.5173,
#         0.3629, 0.2879, 0.5389, 0.4371, 0.1803, 0.3917, 0.3335, 0.6685, 0.1963,
#         0.1819, 0.2879, 0.2028, 0.3234, 0.2403, 0.3450, 0.5634, 0.2618, 0.4221,
#         0.2913, 0.4278, 0.0793, 0.5270, 0.3064])
# sparsitymean tensor(0.3768)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38989.3320)
# cosine similarity tensor(0.4821)
# perplexity tensor(-38110.1133)
# mean cs spread tensor(0.0378)
#
#
# current iteration: 700
# kappa mean tensor(17334.7578)
# kappas tensor([[19413.9355],
#         [19263.1738],
#         [19332.2656],
#         [23637.1172],
#         [20943.5449],
#         [19888.4434],
#         [22268.9902],
#         [19907.2539],
#         [16647.9121],
#         [21308.4297],
#         [18040.3379],
#         [16007.1963],
#         [19257.6289],
#         [16845.3242],
#         [21013.4473],
#         [16614.9336],
#         [20556.7539],
#         [16324.8613],
#         [18092.4316],
#         [18659.9414],
#         [14759.5820],
#         [17891.8242],
#         [15638.4795],
#         [19275.4355],
#         [16686.7754],
#         [15502.3926],
#         [15047.9707],
#         [16630.5664],
#         [17725.4980],
#         [15187.0342],
#         [16774.4414],
#         [14798.3447],
#         [17557.1133],
#         [15295.9531],
#         [16291.3896],
#         [18798.1250],
#         [14383.5215],
#         [17182.7773],
#         [15504.4316],
#         [15814.3848],
#         [15904.3818],
#         [16489.0547],
#         [15171.8779],
#         [13528.3545],
#         [16380.2812],
#         [18122.5039],
#         [14742.6357],
#         [13176.2109],
#         [16839.9453],
#         [15612.7871]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3924, 0.3288, 0.5221, 0.2237, 0.6379, 0.3163, 0.6847, 0.2311, 0.4272,
#         0.2094, 0.3032, 0.1817, 0.5071, 0.3437, 0.6278, 0.3683, 0.5490, 0.2985,
#         0.4925, 0.5209, 0.2366, 0.6681, 0.4127, 0.4855, 0.2035, 0.3396, 0.5212,
#         0.3655, 0.2838, 0.5377, 0.4357, 0.1757, 0.3957, 0.3373, 0.6678, 0.2003,
#         0.1856, 0.2854, 0.2057, 0.3206, 0.2324, 0.3454, 0.5626, 0.2608, 0.4189,
#         0.2903, 0.4323, 0.0783, 0.5238, 0.3074])
# sparsitymean tensor(0.3777)
# pi sums tensor(4934.) 4934
# log likelihood tensor(38996.4062)
# cosine similarity tensor(0.4826)
# perplexity tensor(-38116.6641)
# mean cs spread tensor(0.0354)
#
#
# current iteration: 800
# kappa mean tensor(17852.1680)
# kappas tensor([[19928.6484],
#         [19744.0449],
#         [19855.2051],
#         [24071.9258],
#         [21493.5625],
#         [20366.3477],
#         [22855.8789],
#         [20403.7637],
#         [17086.0234],
#         [21903.8691],
#         [18680.0586],
#         [16498.7695],
#         [19833.3086],
#         [17349.0312],
#         [21542.2520],
#         [17040.0059],
#         [21124.5801],
#         [16861.7949],
#         [18498.5410],
#         [19106.7051],
#         [15171.7939],
#         [18384.7891],
#         [16076.0381],
#         [19763.9688],
#         [17315.0527],
#         [15998.6445],
#         [15526.9307],
#         [17048.9941],
#         [18265.7305],
#         [15651.9609],
#         [17252.2344],
#         [15268.0068],
#         [18574.7051],
#         [15771.7900],
#         [16725.6934],
#         [19302.1230],
#         [14884.7627],
#         [17750.5527],
#         [16038.6377],
#         [16449.8477],
#         [16485.6133],
#         [17027.7266],
#         [15632.4238],
#         [13962.3633],
#         [16815.5410],
#         [18756.5977],
#         [15138.2617],
#         [13826.7637],
#         [17511.6074],
#         [15984.9121]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3941, 0.3327, 0.5232, 0.2271, 0.6384, 0.3168, 0.6893, 0.2345, 0.4299,
#         0.2075, 0.3159, 0.1833, 0.5078, 0.3405, 0.6294, 0.3717, 0.5464, 0.2961,
#         0.4912, 0.5210, 0.2361, 0.6714, 0.4138, 0.4857, 0.2047, 0.3341, 0.5307,
#         0.3634, 0.2824, 0.5374, 0.4402, 0.1746, 0.3924, 0.3397, 0.6703, 0.1994,
#         0.1842, 0.2879, 0.2049, 0.3175, 0.2290, 0.3456, 0.5655, 0.2612, 0.4142,
#         0.2886, 0.4342, 0.0765, 0.5255, 0.3060])
# sparsitymean tensor(0.3783)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39002.0977)
# cosine similarity tensor(0.4831)
# perplexity tensor(-38118.5938)
# mean cs spread tensor(0.0332)
#
#
# current iteration: 900
# kappa mean tensor(18317.3301)
# kappas tensor([[20407.8027],
#         [20258.8359],
#         [20310.5645],
#         [24480.7344],
#         [21989.1250],
#         [20810.4590],
#         [23360.0645],
#         [20903.5566],
#         [17489.4004],
#         [22428.7637],
#         [19226.9219],
#         [16855.3516],
#         [20319.6895],
#         [17750.2812],
#         [22013.8379],
#         [17381.3574],
#         [21574.7090],
#         [17281.5137],
#         [18964.8613],
#         [19500.9395],
#         [15520.1768],
#         [18894.4512],
#         [16416.0449],
#         [20191.9863],
#         [17829.7207],
#         [16385.7031],
#         [15958.3145],
#         [17441.4746],
#         [18726.0156],
#         [16089.1201],
#         [17669.4434],
#         [15688.2861],
#         [19471.9863],
#         [16147.2988],
#         [17141.1680],
#         [19791.6953],
#         [15651.3291],
#         [18308.3652],
#         [16524.4570],
#         [17053.5410],
#         [16973.5586],
#         [17518.1289],
#         [16043.5527],
#         [14292.3838],
#         [17234.2656],
#         [19308.8379],
#         [15536.1885],
#         [14383.5420],
#         [18065.4727],
#         [16301.2363]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3948, 0.3603, 0.5247, 0.2347, 0.6448, 0.3202, 0.6930, 0.2237, 0.4430,
#         0.2089, 0.3215, 0.1843, 0.5145, 0.3325, 0.6245, 0.4077, 0.5488, 0.2948,
#         0.4950, 0.5235, 0.2359, 0.6724, 0.4139, 0.4826, 0.1926, 0.3045, 0.5303,
#         0.3630, 0.2845, 0.5452, 0.4392, 0.1597, 0.3783, 0.3345, 0.6734, 0.2002,
#         0.6452, 0.2858, 0.2040, 0.3046, 0.2249, 0.3429, 0.5600, 0.2613, 0.4050,
#         0.2857, 0.4448, 0.0789, 0.5284, 0.3008])
# sparsitymean tensor(0.3876)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39011.1406)
# cosine similarity tensor(0.4834)
# perplexity tensor(-38114.1328)
# mean cs spread tensor(0.0319)
#
#
# current iteration: 1000
# kappa mean tensor(18729.7812)
# kappas tensor([[20811.3281],
#         [20683.1387],
#         [20681.1641],
#         [24837.7207],
#         [22495.7695],
#         [21197.0312],
#         [23837.0059],
#         [21360.2520],
#         [17879.4121],
#         [22896.0215],
#         [19744.9297],
#         [17205.1289],
#         [20761.5742],
#         [18102.3945],
#         [22452.3750],
#         [17635.5215],
#         [21984.8203],
#         [17644.8398],
#         [19371.1992],
#         [19863.2637],
#         [15855.5645],
#         [19320.0508],
#         [16718.6738],
#         [20560.0742],
#         [18261.6094],
#         [16699.3633],
#         [16344.5020],
#         [17791.9180],
#         [19147.5742],
#         [16454.5156],
#         [18073.8379],
#         [16060.2285],
#         [20292.8027],
#         [16487.4043],
#         [17466.6445],
#         [20206.2422],
#         [16452.5410],
#         [18739.6973],
#         [16955.8359],
#         [17524.7656],
#         [17466.7930],
#         [17904.3711],
#         [16329.9014],
#         [14596.8428],
#         [17623.4082],
#         [19840.1367],
#         [15837.4707],
#         [14882.7705],
#         [18572.4121],
#         [16576.3086]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3958, 0.3615, 0.5243, 0.2381, 0.6454, 0.3202, 0.6946, 0.2261, 0.4440,
#         0.2079, 0.3677, 0.1819, 0.5103, 0.3294, 0.6258, 0.4095, 0.5508, 0.2925,
#         0.4935, 0.5258, 0.2337, 0.6748, 0.4185, 0.4873, 0.1972, 0.3024, 0.5312,
#         0.3637, 0.2871, 0.5439, 0.4398, 0.1587, 0.3804, 0.3382, 0.6760, 0.2011,
#         0.6444, 0.2844, 0.2035, 0.2982, 0.2149, 0.3446, 0.5612, 0.2630, 0.3943,
#         0.2906, 0.4465, 0.0784, 0.5294, 0.3028])
# sparsitymean tensor(0.3887)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39015.2188)
# cosine similarity tensor(0.4837)
# perplexity tensor(-38117.8125)
# mean cs spread tensor(0.0302)
#
# topic topics lda document documents dirichlet word latent words model
# matrix rank pca matrices subspace completion entries norm principal singular
# clustering cluster clusters data algorithm spectral means points partition cut
# variational posterior gaussian bayesian prior inference covariance likelihood log latent
# kernel kernels learning space feature hilbert function data matrix regression
# units layer hidden deep unit layers learning input rbm weights
# policy policies action state reward gradient function value reinforcement iteration
# unlabeled supervised labeled label learning semi labels data classification training
# manifold data tangent points embedding isomap local dimensional dimensionality manifolds
# bound bounds theorem lemma let proof complexity probability error rademacher
# neurons neuron stimulus population tuning neural stimuli firing coding visual
# belief propagation message inference messages energy bethe variables loopy marginals
# network networks neural recurrent input output nodes node training weights
# svm margin support dual problem solution vector svms training machines
# spike spikes firing trains neuron time rate spiking poisson timing
# speech speaker recognition acoustic hmm phoneme signal speakers auditory phonetic
# regret bandit algorithm arm online bound bandits arms armed reward
# active query learning algorithm queries label passive labels hypothesis learner
# graph graphs edge edges nodes vertices vertex node graphical cut
# tree node trees nodes leaf decision root search hierarchical depth
# motor control arm movement trajectory robot movements feedback system position
# submodular functions greedy function algorithm submodularity set monotone problem approximation
# boosting adaboost weak margin learner algorithm hypothesis learners hypotheses examples
# image images pixel pixels patches resolution segmentation texture patch wavelet
# training error learning generalization noise weight teacher student examples weights
# ica source sources separation blind signals signal mixing independent component
# saliency visual eye feature attention map fixation target features image
# player game games players equilibrium nash strategy equilibria strategies regret
# lasso sparse sparsity regression norm regularization selection features group feature
# privacy private differentially differential data mechanism parties dwork queries preserving
# object objects features detection scene feature image appearance views recognition
# subjects stimulus stimuli human response brain trial task trials subject
# model models data latent mixture likelihood variables parameters conditional distribution
# metric distance lmnn nearest learning neighbor similarity distances metrics euclidean
# motion velocity flow motions direction tracking visual human frame frames
# gradient convex convergence optimization stochastic descent algorithm sgd rate dual
# tensor rank tensors norm completion decomposition latent mode matrix schatten
# state states time hmm transition markov sequence hmms dynamics hidden
# sampling gibbs distribution sampler mcmc samples monte carlo sample chain
# classifier classifiers classification training class risk feature features bayes decision
# estimator density estimators estimation entropy estimate distribution variance risk bias
# agent reward agents action actions state learning reinforcement pomdp planning
# ranking query rank items ndcg documents preference pairwise rankings ranked
# ocular dominance eye orientation cortical cortex map visual maps receptive
# cells cell receptive response stimulus responses field spatial visual cortex
# synaptic neuron synapses neurons learning rule plasticity postsynaptic synapse stdp
# word words language sentence sentences context semantic training character corpus
# copula dropout causal price buyer gamma music binding market protein
# loss risk convex function prediction losses online hinge learning functions
# chip circuit analog voltage circuits synapse digital pulse gate output
#
#
# current iteration: 1100
# kappa mean tensor(19103.7500)
# kappas tensor([[21154.2441],
#         [21090.6562],
#         [20959.6777],
#         [25175.5898],
#         [22862.0312],
#         [21533.4512],
#         [24242.9004],
#         [21746.3184],
#         [18173.9473],
#         [23316.7285],
#         [20189.2695],
#         [17489.6836],
#         [21179.3008],
#         [18477.3242],
#         [22839.1914],
#         [17861.9629],
#         [22390.4297],
#         [18023.2227],
#         [19724.0273],
#         [20234.5977],
#         [16157.4902],
#         [19680.3984],
#         [17009.1016],
#         [20904.6426],
#         [18683.0020],
#         [17006.2168],
#         [16601.7363],
#         [18120.9980],
#         [19514.0312],
#         [16765.1543],
#         [18427.6875],
#         [16461.2090],
#         [21037.5000],
#         [16809.2051],
#         [17823.4062],
#         [20590.1133],
#         [17134.1270],
#         [19144.8574],
#         [17337.7480],
#         [18000.7891],
#         [17905.2715],
#         [18273.5137],
#         [16668.5840],
#         [14894.0225],
#         [18000.8535],
#         [20277.6016],
#         [16183.4102],
#         [15352.0811],
#         [18967.4258],
#         [16790.7246]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3960, 0.3609, 0.5265, 0.2374, 0.6470, 0.3163, 0.6964, 0.2260, 0.4410,
#         0.2112, 0.4781, 0.1821, 0.5048, 0.3263, 0.6121, 0.4047, 0.5527, 0.2904,
#         0.4964, 0.5264, 0.2327, 0.6745, 0.4164, 0.4861, 0.1997, 0.3038, 0.5239,
#         0.3661, 0.2862, 0.5418, 0.4418, 0.1909, 0.3782, 0.3395, 0.6742, 0.2014,
#         0.6434, 0.2813, 0.2028, 0.2940, 0.2091, 0.3433, 0.5597, 0.2643, 0.3783,
#         0.3043, 0.4456, 0.0769, 0.5298, 0.3012])
# sparsitymean tensor(0.3905)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39018.8906)
# cosine similarity tensor(0.4839)
# perplexity tensor(-38115.6992)
# mean cs spread tensor(0.0293)
#
#
# current iteration: 1200
# kappa mean tensor(19444.8535)
# kappas tensor([[21492.8828],
#         [21465.4629],
#         [21250.0781],
#         [25421.7578],
#         [23264.7734],
#         [21877.7480],
#         [24610.6191],
#         [22057.9805],
#         [18468.8730],
#         [23704.1172],
#         [20568.4121],
#         [17799.0566],
#         [21563.4805],
#         [18801.6660],
#         [23192.5117],
#         [18097.0020],
#         [22753.0723],
#         [18323.7109],
#         [20055.8770],
#         [20542.6543],
#         [16403.5859],
#         [19995.0078],
#         [17266.7012],
#         [21224.4238],
#         [19070.9746],
#         [17246.7910],
#         [16875.7461],
#         [18381.1914],
#         [19845.3594],
#         [17056.3828],
#         [18740.3125],
#         [16826.6328],
#         [21711.3594],
#         [17108.3164],
#         [18099.7441],
#         [20921.2812],
#         [17784.2598],
#         [19509.2773],
#         [17745.0938],
#         [18439.1250],
#         [18381.2637],
#         [18622.9648],
#         [16927.5801],
#         [15160.2178],
#         [18304.0527],
#         [20591.6270],
#         [16474.4258],
#         [15790.2090],
#         [19404.4297],
#         [17022.6523]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3979, 0.3630, 0.5282, 0.2423, 0.6492, 0.3092, 0.6980, 0.2317, 0.4436,
#         0.2078, 0.4802, 0.1827, 0.4920, 0.3214, 0.6084, 0.4091, 0.5533, 0.2870,
#         0.4951, 0.5273, 0.2304, 0.6747, 0.4194, 0.4877, 0.1996, 0.3062, 0.5287,
#         0.3657, 0.2851, 0.5439, 0.4395, 0.2075, 0.3766, 0.3395, 0.6788, 0.2015,
#         0.6426, 0.2856, 0.2030, 0.2828, 0.2109, 0.3436, 0.5611, 0.2640, 0.3861,
#         0.3072, 0.4435, 0.0775, 0.5243, 0.3049])
# sparsitymean tensor(0.3910)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39021.9453)
# cosine similarity tensor(0.4842)
# perplexity tensor(-38122.3047)
# mean cs spread tensor(0.0282)
#
#
# current iteration: 1300
# kappa mean tensor(19751.2500)
# kappas tensor([[21808.1211],
#         [21859.4785],
#         [21513.4082],
#         [25668.4043],
#         [23557.9473],
#         [22142.4609],
#         [24908.1777],
#         [22372.2441],
#         [18718.9238],
#         [24054.2617],
#         [20933.4590],
#         [18038.5000],
#         [21891.2051],
#         [19104.6211],
#         [23545.3867],
#         [18304.8691],
#         [23062.4512],
#         [18607.1191],
#         [20352.6445],
#         [20821.4414],
#         [16597.9258],
#         [20274.4082],
#         [17500.5742],
#         [21478.3145],
#         [19411.2285],
#         [17512.2051],
#         [17157.3223],
#         [18645.1973],
#         [20185.4473],
#         [17333.6602],
#         [19004.6250],
#         [17171.5840],
#         [22356.8770],
#         [17365.9570],
#         [18341.6367],
#         [21254.2305],
#         [18357.7500],
#         [19838.8809],
#         [18081.6309],
#         [18821.7422],
#         [18771.2715],
#         [18937.4375],
#         [17194.8379],
#         [15412.8398],
#         [18560.4492],
#         [20870.0859],
#         [16733.4473],
#         [16185.5537],
#         [19726.8809],
#         [17213.3105]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4004, 0.3615, 0.5291, 0.2445, 0.6501, 0.3094, 0.7000, 0.2328, 0.4463,
#         0.2123, 0.4794, 0.1839, 0.4919, 0.3153, 0.6104, 0.4091, 0.5523, 0.2852,
#         0.4965, 0.5278, 0.2312, 0.6774, 0.4182, 0.4891, 0.2006, 0.3053, 0.5304,
#         0.3648, 0.2852, 0.5470, 0.4424, 0.2089, 0.3758, 0.3390, 0.6784, 0.2012,
#         0.6439, 0.2856, 0.2017, 0.2788, 0.2064, 0.3465, 0.5655, 0.2621, 0.3903,
#         0.3025, 0.4456, 0.0775, 0.5267, 0.3006])
# sparsitymean tensor(0.3913)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39024.3984)
# cosine similarity tensor(0.4843)
# perplexity tensor(-38121.0703)
# mean cs spread tensor(0.0270)
#
#
# current iteration: 1400
# kappa mean tensor(20033.3281)
# kappas tensor([[22086.1348],
#         [22190.5977],
#         [21778.4961],
#         [25869.5762],
#         [23863.7500],
#         [22417.7910],
#         [25206.5391],
#         [22621.5391],
#         [18921.5703],
#         [24380.0215],
#         [21282.5664],
#         [18339.4824],
#         [22185.5391],
#         [19423.4609],
#         [23847.1172],
#         [18510.7988],
#         [23323.3789],
#         [18883.4648],
#         [20594.4746],
#         [21087.2090],
#         [16791.5879],
#         [20541.4102],
#         [17675.5391],
#         [21730.7207],
#         [19732.9375],
#         [17726.4023],
#         [17404.0293],
#         [18868.5898],
#         [20451.9375],
#         [17597.4375],
#         [19246.7598],
#         [17545.7305],
#         [22916.3086],
#         [17628.4629],
#         [18524.6055],
#         [21560.4727],
#         [18899.8340],
#         [20153.3965],
#         [18376.0137],
#         [19183.1914],
#         [19113.5586],
#         [19204.6797],
#         [17393.1973],
#         [15617.8701],
#         [18839.4043],
#         [21143.9395],
#         [16932.3438],
#         [16561.9258],
#         [20064.4805],
#         [17426.1836]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3971, 0.3630, 0.5276, 0.2445, 0.6473, 0.3066, 0.7043, 0.2321, 0.4450,
#         0.2124, 0.4793, 0.1824, 0.4889, 0.3086, 0.6134, 0.4096, 0.5555, 0.2846,
#         0.4976, 0.5276, 0.2321, 0.6781, 0.4219, 0.4924, 0.1994, 0.3059, 0.5285,
#         0.3653, 0.2827, 0.5466, 0.4421, 0.2085, 0.3758, 0.3400, 0.6789, 0.2025,
#         0.6454, 0.2842, 0.2022, 0.2729, 0.2040, 0.3443, 0.5634, 0.2589, 0.3913,
#         0.3051, 0.4477, 0.0781, 0.5294, 0.3020])
# sparsitymean tensor(0.3911)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39026.7305)
# cosine similarity tensor(0.4845)
# perplexity tensor(-38114.2891)
# mean cs spread tensor(0.0260)
#
#
# current iteration: 1500
# kappa mean tensor(20295.4570)
# kappas tensor([[22333.1035],
#         [22463.8105],
#         [22020.2500],
#         [26058.4434],
#         [24115.0781],
#         [22660.3750],
#         [25477.9180],
#         [22873.7715],
#         [19161.1641],
#         [24644.7402],
#         [21613.4160],
#         [18557.7500],
#         [22466.0059],
#         [19677.6328],
#         [24184.7676],
#         [18712.2988],
#         [23601.3770],
#         [19106.9941],
#         [20821.3848],
#         [21314.6777],
#         [16972.8574],
#         [20788.7383],
#         [17865.2656],
#         [21967.6699],
#         [20016.7930],
#         [17923.1211],
#         [17638.4395],
#         [19006.9297],
#         [20739.5117],
#         [17834.8633],
#         [19437.3535],
#         [17857.9336],
#         [23410.3809],
#         [17857.2617],
#         [18730.0996],
#         [21912.9121],
#         [19406.7051],
#         [20409.5234],
#         [18689.1504],
#         [19515.4375],
#         [19446.2129],
#         [19519.7812],
#         [17575.5840],
#         [15817.2256],
#         [19083.5273],
#         [21393.3711],
#         [17154.2695],
#         [16961.5918],
#         [20345.7676],
#         [17629.6406]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3986, 0.3625, 0.5282, 0.2479, 0.6492, 0.3089, 0.7050, 0.2321, 0.4425,
#         0.2106, 0.4804, 0.1845, 0.4846, 0.3056, 0.6098, 0.4098, 0.5571, 0.2802,
#         0.4949, 0.5297, 0.2316, 0.6798, 0.4212, 0.4895, 0.2017, 0.3039, 0.5363,
#         0.3625, 0.2817, 0.5448, 0.4432, 0.2078, 0.3751, 0.3404, 0.6773, 0.2032,
#         0.6449, 0.2826, 0.2003, 0.2713, 0.2013, 0.3423, 0.5609, 0.2571, 0.3907,
#         0.3032, 0.4412, 0.0776, 0.5272, 0.3000])
# sparsitymean tensor(0.3904)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39028.7227)
# cosine similarity tensor(0.4847)
# perplexity tensor(-38111.1523)
# mean cs spread tensor(0.0253)
#
#
# current iteration: 1600
# kappa mean tensor(20541.2812)
# kappas tensor([[22586.6367],
#         [22741.6953],
#         [22225.6387],
#         [26256.3242],
#         [24381.6387],
#         [22854.3047],
#         [25724.1152],
#         [23135.1523],
#         [19319.7734],
#         [24939.2031],
#         [21909.7109],
#         [18778.8418],
#         [22730.6074],
#         [19957.5098],
#         [24450.1504],
#         [18881.0156],
#         [23836.7949],
#         [19347.5723],
#         [21072.5684],
#         [21541.4512],
#         [17161.7637],
#         [21060.9688],
#         [18094.4922],
#         [22150.6719],
#         [20239.8555],
#         [18124.1602],
#         [17852.0195],
#         [19123.7090],
#         [20987.5762],
#         [18087.2969],
#         [19648.3008],
#         [18136.9062],
#         [23943.4844],
#         [18097.7754],
#         [18940.1074],
#         [22167.8945],
#         [19844.8594],
#         [20629.6406],
#         [18968.0332],
#         [19880.7754],
#         [19753.9414],
#         [19744.2266],
#         [17781.3340],
#         [15997.5635],
#         [19309.2031],
#         [21627.0488],
#         [17351.5312],
#         [17268.5332],
#         [20626.3359],
#         [17793.4355]])
# mu norms tensor(50.) 50
# sparsity tensor([0.4007, 0.3630, 0.5292, 0.2488, 0.6473, 0.3081, 0.7048, 0.2327, 0.4423,
#         0.2094, 0.4764, 0.1826, 0.4859, 0.2986, 0.6073, 0.4078, 0.5567, 0.2807,
#         0.4978, 0.5287, 0.2317, 0.6800, 0.4234, 0.4905, 0.1973, 0.3044, 0.5388,
#         0.3639, 0.2808, 0.5446, 0.4385, 0.2098, 0.3719, 0.3415, 0.6784, 0.2044,
#         0.6433, 0.2823, 0.2007, 0.2669, 0.1974, 0.3416, 0.5668, 0.2565, 0.3917,
#         0.2997, 0.4442, 0.0771, 0.5323, 0.3012])
# sparsitymean tensor(0.3902)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39030.5195)
# cosine similarity tensor(0.4848)
# perplexity tensor(-38120.9023)
# mean cs spread tensor(0.0245)
#
#
# current iteration: 1700
# kappa mean tensor(20767.0723)
# kappas tensor([[22793.3242],
#         [22964.5215],
#         [22438.1113],
#         [26458.2363],
#         [24630.6543],
#         [23073.5234],
#         [25953.2441],
#         [23391.6328],
#         [19481.8066],
#         [25177.2344],
#         [22167.1270],
#         [18972.8555],
#         [23015.3418],
#         [20140.1328],
#         [24705.2793],
#         [19054.1289],
#         [24037.4707],
#         [19566.4336],
#         [21290.9141],
#         [21708.4629],
#         [17334.2715],
#         [21310.5664],
#         [18261.7715],
#         [22338.1504],
#         [20526.9570],
#         [18319.0723],
#         [18054.6758],
#         [19298.2637],
#         [21217.8262],
#         [18312.7422],
#         [19847.2852],
#         [18406.9805],
#         [24392.0977],
#         [18285.1387],
#         [19124.5430],
#         [22427.6836],
#         [20203.7090],
#         [20878.0410],
#         [19189.2715],
#         [20183.1504],
#         [20046.6660],
#         [19974.7715],
#         [17942.4512],
#         [16143.4238],
#         [19517.3945],
#         [21862.5527],
#         [17513.0527],
#         [17588.8242],
#         [20897.5215],
#         [17934.3496]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4000, 0.3646, 0.5306, 0.2485, 0.6477, 0.3086, 0.7063, 0.2335, 0.4406,
#         0.2142, 0.4755, 0.1845, 0.4873, 0.2955, 0.6090, 0.4095, 0.5545, 0.2793,
#         0.4951, 0.5311, 0.2288, 0.6770, 0.4220, 0.4882, 0.2012, 0.3054, 0.5371,
#         0.3638, 0.2824, 0.5489, 0.4441, 0.2109, 0.3724, 0.3404, 0.6791, 0.2045,
#         0.6437, 0.2831, 0.1992, 0.2615, 0.1964, 0.3440, 0.5664, 0.2576, 0.3959,
#         0.2951, 0.4437, 0.0774, 0.5275, 0.3021])
# sparsitymean tensor(0.3903)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39032.2734)
# cosine similarity tensor(0.4850)
# perplexity tensor(-38113.3945)
# mean cs spread tensor(0.0238)
#
#
# current iteration: 1800
# kappa mean tensor(20976.7617)
# kappas tensor([[23001.9531],
#         [23179.9785],
#         [22620.0273],
#         [26628.1699],
#         [24824.7559],
#         [23312.2422],
#         [26185.1211],
#         [23599.8496],
#         [19663.9805],
#         [25421.1191],
#         [22418.4492],
#         [19202.6172],
#         [23221.1348],
#         [20332.3379],
#         [24956.0293],
#         [19167.5410],
#         [24236.6133],
#         [19775.8770],
#         [21445.1836],
#         [21894.8906],
#         [17488.9883],
#         [21544.6582],
#         [18410.8340],
#         [22508.9492],
#         [20752.8418],
#         [18464.4570],
#         [18222.0898],
#         [19472.3418],
#         [21445.7383],
#         [18483.2227],
#         [20030.8887],
#         [18675.6641],
#         [24798.7812],
#         [18465.7441],
#         [19313.9902],
#         [22620.6172],
#         [20579.0527],
#         [21125.2715],
#         [19442.0234],
#         [20471.3242],
#         [20334.7910],
#         [20165.2637],
#         [18127.7949],
#         [16289.8975],
#         [19679.5449],
#         [22084.8672],
#         [17705.9102],
#         [17855.6836],
#         [21125.1660],
#         [18063.8633]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4011, 0.3622, 0.5306, 0.2498, 0.6517, 0.3086, 0.7066, 0.2328, 0.4454,
#         0.2112, 0.4749, 0.1849, 0.4874, 0.2923, 0.6076, 0.4068, 0.5576, 0.2770,
#         0.4984, 0.5329, 0.2289, 0.6797, 0.4214, 0.4886, 0.1999, 0.3060, 0.5388,
#         0.3641, 0.2788, 0.5475, 0.4430, 0.2117, 0.3737, 0.3397, 0.6800, 0.2036,
#         0.6444, 0.2810, 0.1982, 0.2584, 0.1946, 0.3433, 0.5676, 0.2572, 0.3955,
#         0.2960, 0.4464, 0.0776, 0.5269, 0.2996])
# sparsitymean tensor(0.3902)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39033.8906)
# cosine similarity tensor(0.4851)
# perplexity tensor(-38111.2656)
# mean cs spread tensor(0.0233)
#
#
# current iteration: 1900
# kappa mean tensor(21175.5938)
# kappas tensor([[23197.2363],
#         [23403.8027],
#         [22784.1543],
#         [26756.2305],
#         [25032.0469],
#         [23495.0918],
#         [26392.5117],
#         [23828.6484],
#         [19830.8691],
#         [25666.1699],
#         [22675.5898],
#         [19356.5605],
#         [23433.4355],
#         [20543.4121],
#         [25193.7051],
#         [19295.0801],
#         [24481.4023],
#         [20003.8945],
#         [21568.4980],
#         [22080.5898],
#         [17659.5254],
#         [21764.3711],
#         [18531.6777],
#         [22638.1523],
#         [20972.4863],
#         [18599.4941],
#         [18389.9727],
#         [19622.5254],
#         [21613.8750],
#         [18700.4570],
#         [20229.5605],
#         [18945.2871],
#         [25195.2910],
#         [18670.9492],
#         [19494.6758],
#         [22825.7773],
#         [20901.0879],
#         [21339.9531],
#         [19647.1816],
#         [20771.5410],
#         [20580.0098],
#         [20357.7148],
#         [18304.3672],
#         [16396.0742],
#         [19849.2539],
#         [22278.7754],
#         [17806.6992],
#         [18133.8281],
#         [21349.3574],
#         [18190.9043]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4030, 0.3635, 0.5304, 0.2527, 0.6498, 0.3086, 0.7099, 0.2346, 0.4418,
#         0.2110, 0.4723, 0.1832, 0.4863, 0.2887, 0.6114, 0.4079, 0.5565, 0.2739,
#         0.4988, 0.5321, 0.2308, 0.6813, 0.4237, 0.4900, 0.1980, 0.3056, 0.5386,
#         0.3641, 0.2772, 0.5459, 0.4403, 0.2096, 0.3697, 0.3413, 0.6827, 0.2028,
#         0.6430, 0.2806, 0.1990, 0.2535, 0.1941, 0.3435, 0.5680, 0.2557, 0.3990,
#         0.2963, 0.4440, 0.0766, 0.5202, 0.2985])
# sparsitymean tensor(0.3898)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39035.2930)
# cosine similarity tensor(0.4852)
# perplexity tensor(-38112.2031)
# mean cs spread tensor(0.0227)
#
#
# current iteration: 2000
# kappa mean tensor(21359.9824)
# kappas tensor([[23403.9922],
#         [23582.4219],
#         [22891.9707],
#         [26889.2715],
#         [25222.1543],
#         [23670.5195],
#         [26583.3496],
#         [24035.6113],
#         [20045.1465],
#         [25886.7305],
#         [22891.1992],
#         [19508.6719],
#         [23605.8340],
#         [20775.7910],
#         [25403.5137],
#         [19432.0605],
#         [24686.5254],
#         [20189.5703],
#         [21716.9961],
#         [22252.8184],
#         [17767.3633],
#         [21934.3672],
#         [18658.2695],
#         [22818.6191],
#         [21186.3301],
#         [18734.5820],
#         [18546.8770],
#         [19805.1836],
#         [21800.4551],
#         [18904.4746],
#         [20376.6953],
#         [19146.7344],
#         [25560.2031],
#         [18840.0527],
#         [19657.0547],
#         [23042.9668],
#         [21205.1094],
#         [21583.1797],
#         [19864.9668],
#         [21024.0527],
#         [20806.4004],
#         [20513.2598],
#         [18432.6719],
#         [16502.2812],
#         [19990.8438],
#         [22454.9727],
#         [17924.7168],
#         [18408.7129],
#         [21541.5078],
#         [18292.0547]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3997, 0.3661, 0.5310, 0.2540, 0.6505, 0.3099, 0.7082, 0.2315, 0.4429,
#         0.2119, 0.4751, 0.1843, 0.4840, 0.2819, 0.6102, 0.4112, 0.5574, 0.2746,
#         0.4986, 0.5310, 0.2279, 0.6842, 0.4221, 0.4876, 0.1973, 0.3043, 0.5421,
#         0.3656, 0.2769, 0.5476, 0.4448, 0.2114, 0.3712, 0.3431, 0.6816, 0.2040,
#         0.6449, 0.2831, 0.2007, 0.2534, 0.1918, 0.3442, 0.5636, 0.2561, 0.3962,
#         0.2897, 0.4478, 0.0770, 0.5250, 0.3015])
# sparsitymean tensor(0.3900)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39036.5781)
# cosine similarity tensor(0.4853)
# perplexity tensor(-38119.2930)
# ...
#         [21541.6211],
#         [25970.6172],
#         [25411.8633],
#         [24504.9180],
#         [23127.3672],
#         [25006.7832],
#         [24387.3203],
#         [22844.4219],
#         [20216.8184],
#         [18245.4570],
#         [21969.4941],
#         [25159.6816],
#         [19847.3633],
#         [22190.7852],
#         [24562.4961],
#         [19679.9258]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4068, 0.3694, 0.5362, 0.2981, 0.6526, 0.3228, 0.7164, 0.2240, 0.4441,
#         0.2099, 0.4635, 0.1901, 0.5050, 0.1638, 0.6070, 0.4096, 0.5625, 0.2460,
#         0.5004, 0.5384, 0.2246, 0.6953, 0.4267, 0.4847, 0.1620, 0.2996, 0.5578,
#         0.3654, 0.2750, 0.5455, 0.4456, 0.1978, 0.3707, 0.3422, 0.6859, 0.2138,
#         0.6475, 0.2774, 0.1964, 0.2139, 0.1757, 0.3420, 0.5618, 0.2404, 0.3962,
#         0.2755, 0.4429, 0.0747, 0.5191, 0.2994])
# sparsitymean tensor(0.3864)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39051.9727)
# cosine similarity tensor(0.4866)
# perplexity tensor(-38103.5117)
# mean cs spread tensor(0.0154)
#
#
# current iteration: 4500
# kappa mean tensor(24017.1602)
# kappas tensor([[25849.6973],
#         [26207.5137],
#         [24994.9102],
#         [28882.5371],
#         [27941.8594],
#         [26207.9648],
#         [29140.1387],
#         [27149.7480],
#         [22376.5352],
#         [29039.1465],
#         [26067.7520],
#         [21581.2656],
#         [26652.0742],
#         [24473.9336],
#         [28236.9277],
#         [21157.0098],
#         [27305.7109],
#         [23144.5898],
#         [23880.5352],
#         [24447.7852],
#         [19921.8379],
#         [24470.6523],
#         [20294.4766],
#         [25245.5586],
#         [24452.4746],
#         [20610.7305],
#         [20767.9375],
#         [21489.8809],
#         [24594.7051],
#         [21318.8516],
#         [22616.1250],
#         [22374.3711],
#         [31164.6660],
#         [21036.7227],
#         [21597.2441],
#         [26042.4668],
#         [25518.7500],
#         [24542.7070],
#         [23203.4219],
#         [25143.7910],
#         [24465.7910],
#         [22915.5547],
#         [20271.1367],
#         [18294.7637],
#         [22033.0996],
#         [25219.0391],
#         [19860.6816],
#         [22315.5781],
#         [24637.8105],
#         [19699.5254]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4079, 0.3685, 0.5358, 0.2999, 0.6529, 0.3246, 0.7211, 0.2233, 0.4384,
#         0.2099, 0.4625, 0.1890, 0.5046, 0.1647, 0.6107, 0.4091, 0.5652, 0.2433,
#         0.5026, 0.5390, 0.2236, 0.6971, 0.4283, 0.4862, 0.1620, 0.3022, 0.5546,
#         0.3648, 0.2746, 0.5495, 0.4439, 0.1978, 0.3679, 0.3391, 0.6867, 0.2122,
#         0.6520, 0.2788, 0.1955, 0.2125, 0.1768, 0.3429, 0.5584, 0.2411, 0.3920,
#         0.2787, 0.4441, 0.0734, 0.5212, 0.2990])
# sparsitymean tensor(0.3866)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39052.3125)
# cosine similarity tensor(0.4867)
# perplexity tensor(-38102.7461)
# mean cs spread tensor(0.0152)
#
#
# current iteration: 4600
# kappa mean tensor(24079.6191)
# kappas tensor([[25916.6250],
#         [26277.5840],
#         [25044.5684],
#         [28882.9141],
#         [27990.5352],
#         [26311.0039],
#         [29181.9785],
#         [27217.4785],
#         [22424.4375],
#         [29132.5898],
#         [26149.3242],
#         [21646.4082],
#         [26728.9082],
#         [24594.5938],
#         [28271.7051],
#         [21217.5039],
#         [27330.9883],
#         [23235.5176],
#         [23902.9082],
#         [24501.3945],
#         [19965.1816],
#         [24535.1328],
#         [20387.7441],
#         [25274.4414],
#         [24563.7344],
#         [20670.2559],
#         [20831.2285],
#         [21529.1777],
#         [24611.7461],
#         [21304.4922],
#         [22652.8652],
#         [22432.9355],
#         [31316.1855],
#         [21075.6816],
#         [21656.5703],
#         [26098.9453],
#         [25604.6211],
#         [24676.3516],
#         [23302.6289],
#         [25234.9590],
#         [24543.3965],
#         [22975.6191],
#         [20287.7168],
#         [18327.1387],
#         [22110.1445],
#         [25283.8516],
#         [19888.3008],
#         [22387.4902],
#         [24745.8711],
#         [19747.6523]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4084, 0.3658, 0.5355, 0.2968, 0.6539, 0.3245, 0.7183, 0.2230, 0.4420,
#         0.2081, 0.4632, 0.1911, 0.5017, 0.1614, 0.6083, 0.4081, 0.5633, 0.2396,
#         0.5024, 0.5379, 0.2233, 0.6986, 0.4256, 0.4828, 0.1613, 0.3016, 0.5576,
#         0.3653, 0.2735, 0.5493, 0.4448, 0.1961, 0.3698, 0.3387, 0.6873, 0.2127,
#         0.6502, 0.2772, 0.1938, 0.2135, 0.1759, 0.3414, 0.5575, 0.2426, 0.3947,
#         0.2752, 0.4454, 0.0740, 0.5250, 0.3001])
# sparsitymean tensor(0.3862)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39052.6562)
# cosine similarity tensor(0.4867)
# perplexity tensor(-38096.1211)
# mean cs spread tensor(0.0152)
#
#
# current iteration: 4700
# kappa mean tensor(24140.2188)
# kappas tensor([[25962.3945],
#         [26282.6211],
#         [25111.1699],
#         [28921.1973],
#         [28049.3750],
#         [26366.0938],
#         [29218.5234],
#         [27270.3750],
#         [22501.4473],
#         [29210.5762],
#         [26244.5879],
#         [21684.0020],
#         [26765.2812],
#         [24741.2852],
#         [28350.6250],
#         [21251.8574],
#         [27434.9473],
#         [23323.1113],
#         [23925.6211],
#         [24552.8887],
#         [20021.9902],
#         [24531.6504],
#         [20432.8750],
#         [25352.6934],
#         [24648.4473],
#         [20701.5312],
#         [20885.7773],
#         [21571.0020],
#         [24687.2070],
#         [21354.3301],
#         [22679.9180],
#         [22493.6836],
#         [31436.5742],
#         [21142.6660],
#         [21665.1602],
#         [26189.6836],
#         [25704.7285],
#         [24730.4922],
#         [23386.6973],
#         [25341.0430],
#         [24656.3613],
#         [23030.0234],
#         [20349.0977],
#         [18352.8672],
#         [22177.8691],
#         [25318.6270],
#         [19944.6211],
#         [22499.0078],
#         [24806.0293],
#         [19750.3867]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4102, 0.3644, 0.5369, 0.3042, 0.6552, 0.3212, 0.7188, 0.2229, 0.4455,
#         0.2073, 0.4638, 0.1906, 0.5004, 0.1629, 0.6091, 0.4108, 0.5625, 0.2430,
#         0.4996, 0.5390, 0.2237, 0.6968, 0.4265, 0.4839, 0.1613, 0.3017, 0.5580,
#         0.3656, 0.2755, 0.5466, 0.4439, 0.1982, 0.3690, 0.3357, 0.6857, 0.2110,
#         0.6504, 0.2745, 0.1971, 0.2114, 0.1733, 0.3417, 0.5639, 0.2399, 0.3964,
#         0.2729, 0.4465, 0.0742, 0.5227, 0.3014])
# sparsitymean tensor(0.3864)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39052.9258)
# cosine similarity tensor(0.4867)
# perplexity tensor(-38100.0742)
# mean cs spread tensor(0.0149)
#
#
# current iteration: 4800
# kappa mean tensor(24197.3848)
# kappas tensor([[26033.8105],
#         [26367.2734],
#         [25142.2969],
#         [28963.1895],
#         [28124.4863],
#         [26397.0410],
#         [29281.5273],
#         [27333.0820],
#         [22573.3516],
#         [29259.8516],
#         [26314.4609],
#         [21706.8047],
#         [26846.5449],
#         [24846.3047],
#         [28416.9199],
#         [21251.2676],
#         [27496.7148],
#         [23380.0098],
#         [23958.7891],
#         [24580.8770],
#         [20031.2324],
#         [24574.3789],
#         [20421.8691],
#         [25392.1719],
#         [24747.3086],
#         [20759.5176],
#         [20959.4277],
#         [21653.2480],
#         [24769.7422],
#         [21416.8867],
#         [22706.6797],
#         [22537.3027],
#         [31545.5742],
#         [21180.5801],
#         [21661.1641],
#         [26259.6484],
#         [25803.3223],
#         [24830.8906],
#         [23487.8027],
#         [25426.9863],
#         [24756.6641],
#         [23079.7461],
#         [20382.3184],
#         [18385.4844],
#         [22198.5801],
#         [25358.8555],
#         [19976.3320],
#         [22618.1914],
#         [24874.6133],
#         [19798.1191]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4088, 0.3671, 0.5336, 0.2975, 0.6512, 0.3197, 0.7182, 0.2236, 0.4394,
#         0.2076, 0.4637, 0.1916, 0.5021, 0.1638, 0.6102, 0.4088, 0.5633, 0.2408,
#         0.5001, 0.5410, 0.2247, 0.6972, 0.4270, 0.4818, 0.1602, 0.3017, 0.5557,
#         0.3654, 0.2736, 0.5479, 0.4425, 0.2003, 0.3709, 0.3402, 0.6863, 0.2135,
#         0.6506, 0.2739, 0.1918, 0.2125, 0.1760, 0.3449, 0.5585, 0.2414, 0.3984,
#         0.2739, 0.4459, 0.0734, 0.5221, 0.2991])
# sparsitymean tensor(0.3861)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39053.1133)
# cosine similarity tensor(0.4867)
# perplexity tensor(-38102.2266)
# mean cs spread tensor(0.0149)
#
#
# current iteration: 4900
# kappa mean tensor(24251.3789)
# kappas tensor([[26074.3926],
#         [26435.9824],
#         [25204.5918],
#         [28997.8770],
#         [28182.8320],
#         [26416.0449],
#         [29333.3770],
#         [27381.9590],
#         [22618.8984],
#         [29327.4336],
#         [26415.6836],
#         [21733.7812],
#         [26921.9668],
#         [24968.2266],
#         [28464.3828],
#         [21273.3320],
#         [27556.6699],
#         [23434.2930],
#         [24063.7109],
#         [24602.9805],
#         [20040.1504],
#         [24614.6836],
#         [20476.7402],
#         [25448.6992],
#         [24837.6152],
#         [20819.2891],
#         [20987.2012],
#         [21654.0156],
#         [24809.2051],
#         [21508.2109],
#         [22729.7578],
#         [22621.7715],
#         [31658.2637],
#         [21220.9941],
#         [21723.6172],
#         [26334.7461],
#         [25914.1270],
#         [24898.9980],
#         [23548.6133],
#         [25527.6562],
#         [24843.2852],
#         [23119.8301],
#         [20399.7910],
#         [18411.1934],
#         [22207.3086],
#         [25412.4297],
#         [20000.9414],
#         [22706.5332],
#         [24893.8262],
#         [19791.0957]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4089, 0.3681, 0.5345, 0.3036, 0.6555, 0.3206, 0.7192, 0.2235, 0.4436,
#         0.2096, 0.4606, 0.1895, 0.5010, 0.1631, 0.6085, 0.4080, 0.5642, 0.2418,
#         0.4995, 0.5389, 0.2234, 0.6971, 0.4299, 0.4829, 0.1641, 0.3009, 0.5568,
#         0.3658, 0.2713, 0.5454, 0.4463, 0.2002, 0.3672, 0.3382, 0.6849, 0.2135,
#         0.6512, 0.2738, 0.1927, 0.2130, 0.1735, 0.3440, 0.5620, 0.2413, 0.3995,
#         0.2740, 0.4484, 0.0743, 0.5204, 0.3010])
# sparsitymean tensor(0.3864)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39053.4727)
# cosine similarity tensor(0.4867)
# perplexity tensor(-38096.9336)
# mean cs spread tensor(0.0148)
#
#
# current iteration: 5000
# kappa mean tensor(24308.0547)
# kappas tensor([[26093.3672],
#         [26499.1113],
#         [25229.6758],
#         [29090.1016],
#         [28244.9551],
#         [26468.0898],
#         [29402.1641],
#         [27462.2480],
#         [22662.7480],
#         [29388.4141],
#         [26508.0547],
#         [21774.7051],
#         [26932.2383],
#         [25113.7910],
#         [28541.9844],
#         [21324.6309],
#         [27539.5371],
#         [23512.0723],
#         [24091.9043],
#         [24625.1816],
#         [20093.5000],
#         [24662.0312],
#         [20504.6934],
#         [25496.4062],
#         [24929.4805],
#         [20852.0449],
#         [21058.0703],
#         [21673.3477],
#         [24844.9590],
#         [21555.0703],
#         [22759.9512],
#         [22669.1016],
#         [31807.1250],
#         [21262.2598],
#         [21771.3848],
#         [26409.8125],
#         [25970.4258],
#         [24962.5781],
#         [23663.6504],
#         [25593.2109],
#         [24922.0137],
#         [23159.5586],
#         [20451.5137],
#         [18430.3203],
#         [22235.1074],
#         [25487.6641],
#         [20046.2578],
#         [22830.7461],
#         [24964.9824],
#         [19830.5840]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.4085, 0.3666, 0.5355, 0.3029, 0.6537, 0.3223, 0.7211, 0.2243, 0.4466,
#         0.2085, 0.4647, 0.1897, 0.5043, 0.1634, 0.6075, 0.4093, 0.5651, 0.2387,
#         0.5010, 0.5387, 0.2232, 0.6973, 0.4281, 0.4836, 0.1618, 0.3009, 0.5649,
#         0.3654, 0.2727, 0.5468, 0.4437, 0.2005, 0.3675, 0.3385, 0.6860, 0.2143,
#         0.6505, 0.2767, 0.1941, 0.2127, 0.1735, 0.3447, 0.5632, 0.2376, 0.3967,
#         0.2726, 0.4428, 0.0743, 0.5194, 0.3007])
# sparsitymean tensor(0.3865)
# pi sums tensor(4934.) 4934
# log likelihood tensor(39053.6133)
# cosine similarity tensor(0.4867)
# perplexity tensor(-38108.0664)
# mean cs spread tensor(0.0146)
#
# topic topics lda document documents dirichlet word words latent hdp
# matrix rank pca matrices subspace principal entries completion singular covariance
# clustering cluster clusters data spectral algorithm means points partition cut
# variational posterior gaussian bayesian inference prior log latent likelihood covariance
# kernel kernels svm learning space hilbert feature function data regression
# units layer hidden deep unit layers rbm learning training weights
# policy policies action state reward function gradient value reinforcement iteration
# unlabeled label supervised labeled learning labels semi data classification task
# manifold data points tangent embedding isomap dimensionality local dimensional manifolds
# bound bounds theorem lemma let error complexity proof learning rademacher
# neurons neuron neural stimulus population spiking firing network dynamics synaptic
# belief propagation message inference messages bethe loopy energy marginals variables
# network networks neural recurrent output input nodes node units weights
# convex dual problem svm optimization solution margin norm constraints primal
# spike spikes firing neuron trains time spiking rate neurons poisson
# speech speaker recognition acoustic hmm signal phoneme auditory speakers noise
# regret bandit algorithm arm online bound bandits arms armed reward
# active algorithm query queries learning label passive algorithms hypothesis labels
# graph graphs edge edges nodes vertices vertex node graphical cut
# tree node trees nodes leaf decision root hierarchical search depth
# motor control arm movement trajectory robot movements feedback system position
# submodular functions greedy function algorithm submodularity monotone set problem approximation
# boosting adaboost weak margin learner algorithm learners hypothesis classifiers base
# image images pixel pixels patches resolution segmentation texture wavelet patch
# noise error training gaussian generalization learning function weight teacher regression
# ica source sources separation blind signals signal mixing components component
# saliency visual feature eye map attention fixation features target image
# player game games players equilibrium nash strategy equilibria strategies play
# lasso sparse sparsity regression features feature selection regularization norm group
# privacy private differentially differential data mechanism dwork queries preserving parties
# object objects features detection scene feature image appearance views recognition
# stimulus subjects stimuli response trial responses human brain trials population
# model models data latent mixture likelihood variables parameters learning training
# metric distance lmnn nearest learning neighbor similarity distances metrics euclidean
# motion velocity flow motions direction tracking visual human frames frame
# gradient stochastic convergence descent optimization sgd rate algorithm convex learning
# tensor rank tensors norm completion decomposition mode latent schatten matrix
# state states time hmm transition markov sequence dynamics hmms sequences
# sampling gibbs distribution mcmc samples sampler monte carlo posterior sample
# classifier svm classifiers training classification class margin feature data risk
# estimator density estimation estimators risk entropy distribution estimate variance gaussian
# agent reward agents action actions state reinforcement pomdp learning planning
# ranking query rank items ndcg documents pairwise preference ranked rankings
# ocular dominance eye orientation cortical cortex visual map activity maps
# cells cell receptive response stimulus responses field spatial visual cortex
# synaptic learning synapses rule plasticity postsynaptic stdp synapse weight hebbian
# word words language sentence sentences training context semantic recognition character
# causal copula gamma latent lifted market buyer dropout price deep
# loss risk convex prediction online losses function hinge margin learning
# chip circuit analog voltage circuits synapse digital gate pulse output

# %% [markdown]
# # Get Topic Coherence

# %%
mu_final = mu_samples / num_samples
kappa_final = kappa_samples / num_samples
theta_final = theta_samples / num_samples
print("final perplexity", vmf_perplexity(tensor_te, mu_final, kappa_final, alpha, N=1000))
emb = mu_final.cpu().numpy()
topics = get_topics(emb, vocab)
print('prior_mu:', prior_mu)
print_summary(topics,method,dataset)

if dataset == '20news':
    pi = dist.StickBreakingTransform()(theta_final)
    pi = pi.cpu().numpy()
    clustering_metrics_20news(pi)
# Out:
# final perplexity tensor(-38096.4688)
# prior_mu: neg
#
# Method  = vptm
# Number of topics = 50
# Dataset = nips
#
#  NPMI       TU         Topic
#  0.04860    0.77000    topic topics lda document documents dirichlet word words latent hdp
#  0.08867    0.78333    matrix rank pca matrices subspace principal entries completion singular covariance
#  0.08778    0.73095    clustering cluster clusters data spectral algorithm means points partition cut
#  0.11839    0.65333    variational posterior gaussian bayesian inference prior log latent likelihood covariance
#  0.09632    0.52929    kernel kernels svm learning space hilbert feature function data regression
#  0.05045    0.67833    units layer hidden deep unit layers rbm learning training weights
#  0.03557    0.63667    policy policies action state reward function gradient value reinforcement iteration
#  0.05889    0.67262    unlabeled label supervised labeled learning labels semi data classification task
#  0.09674    0.86429    manifold data points tangent embedding isomap dimensionality local dimensional manifolds
#  0.09942    0.80833    bound bounds theorem lemma let error complexity proof learning rademacher
#  0.14600    0.48333    neurons neuron neural stimulus population spiking firing network dynamics synaptic
#  0.02368    0.90000    belief propagation message inference messages bethe loopy energy marginals variables
#  0.13764    0.61667    network networks neural recurrent output input nodes node units weights
#  0.09175    0.62500    convex dual problem svm optimization solution margin norm constraints primal
#  0.08511    0.70000    spike spikes firing neuron trains time spiking rate neurons poisson
#  0.08068    0.78333    speech speaker recognition acoustic hmm signal phoneme auditory speakers noise
#  0.02663    0.70000    regret bandit algorithm arm online bound bandits arms armed reward
#  0.07168    0.57500    active algorithm query queries learning label passive algorithms hypothesis labels
#  0.23074    0.81667    graph graphs edge edges nodes vertices vertex node graphical cut
#  0.11701    0.86667    tree node trees nodes leaf decision root hierarchical search depth
#  0.05396    0.95000    motor control arm movement trajectory robot movements feedback system position
#  0.11145    0.78667    submodular functions greedy function algorithm submodularity monotone set problem approximation
#  0.03100    0.74167    boosting adaboost weak margin learner algorithm learners hypothesis classifiers base
#  0.12227    0.93333    image images pixel pixels patches resolution segmentation texture wavelet patch
#  0.08365    0.46500    noise error training gaussian generalization learning function weight teacher regression
#  0.05976    0.95000    ica source sources separation blind signals signal mixing components component
#  0.06504    0.61167    saliency visual feature eye map attention fixation features target image
#  0.11200    1.00000    player game games players equilibrium nash strategy equilibria strategies play
#  0.06460    0.72000    lasso sparse sparsity regression features feature selection regularization norm group
#  0.04520    0.86429    privacy private differentially differential data mechanism dwork queries preserving parties
#  0.05204    0.72000    object objects features detection scene feature image appearance views recognition
#  0.08571    0.73333    stimulus subjects stimuli response trial responses human brain trials population
#  0.10220    0.56262    model models data latent mixture likelihood variables parameters learning training
#  0.08806    0.90833    metric distance lmnn nearest learning neighbor similarity distances metrics euclidean
#  0.07511    0.87500    motion velocity flow motions direction tracking visual human frames frame
#  0.11158    0.60833    gradient stochastic convergence descent optimization sgd rate algorithm convex learning
#  0.06567    0.68667    tensor rank tensors norm completion decomposition mode latent schatten matrix
#  0.02654    0.78333    state states time hmm transition markov sequence dynamics hmms sequences
#  0.13726    0.90000    sampling gibbs distribution mcmc samples sampler monte carlo posterior sample
#  0.04907    0.44595    classifier svm classifiers training classification class margin feature data risk
#  0.15873    0.81667    estimator density estimation estimators risk entropy distribution estimate variance gaussian
#  0.03500    0.67500    agent reward agents action actions state reinforcement pomdp learning planning
#  0.04896    0.83333    ranking query rank items ndcg documents pairwise preference ranked rankings
#  0.11025    0.77500    ocular dominance eye orientation cortical cortex visual map activity maps
#  0.14514    0.70833    cells cell receptive response stimulus responses field spatial visual cortex
#  0.15129    0.75833    synaptic learning synapses rule plasticity postsynaptic stdp synapse weight hebbian
#  0.07547    0.75333    word words language sentence sentences training context semantic recognition character
#  0.01204    0.87000    causal copula gamma latent lifted market buyer dropout price deep
#  0.04275    0.57000    loss risk convex prediction online losses function hinge margin learning
#  0.14404    0.90000    chip circuit analog voltage circuits synapse digital gate pulse output
#
# Mean NPMI = 0.0851518
# Mean TU   = 0.742
