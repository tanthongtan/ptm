# %% [markdown]
# <a href="https://colab.research.google.com/github/tanthongtan/ptm/blob/master/vptm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hyperparameters

# %%
num_topic = 50
dataset = 'nytimes'
method = 'vptm'

#vptm hyperparameters
alpha_scalar = 50./num_topic
v= 0.025
c = 0.02
 
#GMC hyperparameters
num_samples = 1
num_burn = 5000
S = 25000
L = 20
eta_theta = 4e-2
rho_theta = 1e-1
eta_mu = 4e-4
rho_mu = 1e-1
eta_kappa = 2e-1
rho_kappa = 1e-1

# %% [markdown]
# # Run GMC Inference

# %%
#only for google colab
import sys
import os
if 'google.colab' in sys.modules:
    #lets see what gpu we were given
    # !nvidia-smi
    #get repository
    # !git clone https://github.com/tanthongtan/ptm.git
    # %cd '/content/ptm'
    #get ref corp if doesn't exist
    if not os.path.isdir('wiki_final'):
        # !unzip -q "/content/drive/My Drive/wiki_final.zip"
 
import torch
import torch.nn.functional as F
from geodesic import GeodesicMonteCarlo
from dataset import load_data, csr_to_torchsparse
import geodesic as g
import distributions as D
from tqdm.notebook import tqdm
import torch.distributions as dist
import numpy as np
from utils import print_topics, get_topics, vmf_perplexity, clustering_metrics_20news, print_summary
 
#make all tensors cuda if available and double
if torch.cuda.is_available():
    torch.set_default_tensor_type(torch.cuda.FloatTensor)
    gpu = True
else:
    torch.set_default_tensor_type(torch.DoubleTensor)
    gpu = False
 
#Load Data
data_tr, data_te, vocab, vocab_size, num_tr = load_data(use_tfidf = True, sublinear = False, normalize = True, dataset = dataset)    
tensor_te = csr_to_torchsparse(data_te, gpu)

#declare tensor hyperparameters
alpha = torch.full((1,num_topic), alpha_scalar)
mu0 = F.normalize(torch.full((vocab_size,),-1.0),dim=-1)
 
#randomly initialize model parameters
theta = torch.randn(num_tr,num_topic-1)
mu = F.normalize(torch.randn(num_topic, vocab_size) / (vocab_size ** 0.5) + mu0, p=2, dim=-1)
kappa = torch.randn(num_topic,1)*50 + 50. * (vocab_size ** 0.5) 
 
#declare GMC transition kernels
kernel = GeodesicMonteCarlo(L)
params = {'theta': theta, 'mu':mu, 'kappa': kappa}
init_etas = {'theta': eta_theta, 'mu':eta_mu, 'kappa': eta_kappa}
geodesics = {'theta': g.RnGeodesic(eta = eta_theta, rho = rho_theta), 'mu': g.SphericalGeodesic(eta = eta_mu, rho = rho_mu), 'kappa': g.PositiveGeodesic(eta = eta_kappa, rho = rho_kappa)}
vs = {name: geodesics[name].projection(params[name],dist.MultivariateNormal(torch.zeros(params[name].shape[-1]), torch.eye(params[name].shape[-1])).sample([params[name].shape[0]])) for name in params}
 
#start sampling loop
t = tqdm(range(num_samples+num_burn))
theta_samples = 0
mu_samples = 0
kappa_samples = 0
for i in t:
    
    idx = torch.randperm(num_tr)[:S]
    x_batch = csr_to_torchsparse(data_tr[idx.cpu()], gpu)
    theta = params['theta']
    params['theta'] = theta[idx]
    v_theta = vs['theta']
    vs['theta'] = v_theta[idx]
 
    for name in geodesics:
        geodesics[name].eta = init_etas[name] * ((i+1) ** (-1./5.))
    params, vs = kernel.stochastic_transition(params, vs, geodesics, D.VptmJointDistributionWithStickDirConjugatePrior(x_batch, alpha, c, mu0, v))
    
    theta[idx] = params['theta']
    v_theta[idx] = vs['theta']
    params['theta'] = theta
    vs['theta'] = v_theta
    
    theta = params['theta']
    kappa = params['kappa']
    mu = params['mu']
    
    if torch.any(kappa != kappa):
        break
   
    if i >= num_burn:
        theta_samples += theta
        mu_samples += mu
        kappa_samples += kappa

    if i % 100 == 0:
        print("\ncurrent iteration:", i)
        print("kappa mean",kappa.mean())
        print("kappas",kappa)
        pi = dist.StickBreakingTransform()(theta)
        print("mu norms", mu.norm(dim=-1).sum(), num_topic)
        print("sparsity",(torch.abs(mu)**2.).norm(dim=-1))
        print("sparsitymean",(torch.abs(mu)**2.).norm(dim=-1).mean())
        print("pi sums", pi.sum(dim=-1).sum(), num_tr)

        sum_ll = 0.0
        sum_cs = 0.0
        for j in range(int(np.ceil(num_tr/S))):
            curr_pi = pi[j*S:j*S+S]
            curr_tensor_tr = csr_to_torchsparse(data_tr[j*S:j*S+S], gpu)
            curr_avg = torch.matmul(curr_pi,kappa*mu)
            sum_ll += D.log_prob_von_mises_fisher(curr_avg, curr_tensor_tr).sum()
            curr_avg = F.normalize(curr_avg,dim=-1)
            sum_cs += D.sparse_dense_dot(curr_tensor_tr, curr_avg).sum()
        
        print("log likelihood", sum_ll / num_tr)        
        print("cosine similarity", sum_cs / num_tr)
        print("perplexity", vmf_perplexity(tensor_te, mu, kappa, alpha, N=1000),"\n")
        
    if i % 1000 == 0:
        emb = mu.cpu().numpy()
        print_topics(get_topics(emb,vocab))
        print("")
# Out:
# Tue Oct 13 01:59:31 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Cloning into 'ptm'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 343 (delta 31), reused 33 (delta 10), pack-reused 276
# Receiving objects: 100% (343/343), 257.48 MiB | 32.49 MiB/s, done.
# Resolving deltas: 100% (163/163), done.
# /content/ptm
# Dim Training Data (42499, 15000)
# Dim Test Data (7500, 15000)
# HBox(children=(FloatProgress(value=0.0, max=5001.0), HTML(value='')))
# current iteration: 0
# kappa mean tensor(5948.0962)
# kappas tensor([[5765.4355],
#         [5757.1357],
#         [5867.1987],
#         [5913.7695],
#         [5902.4829],
#         [5881.2642],
#         [5875.5059],
#         [5946.0610],
#         [5908.0615],
#         [5753.5024],
#         [5895.1226],
#         [5920.4360],
#         [5870.4253],
#         [5917.7070],
#         [5871.7588],
#         [5796.0103],
#         [5739.5879],
#         [5875.3789],
#         [5988.4458],
#         [5967.6880],
#         [5937.4082],
#         [5896.0190],
#         [5993.0781],
#         [5877.8770],
#         [5905.3594],
#         [5946.0488],
#         [5909.6367],
#         [5977.3628],
#         [5929.0693],
#         [6050.0078],
#         [5979.5151],
#         [6032.4678],
#         [5982.9385],
#         [5956.3340],
#         [5985.7534],
#         [5998.7295],
#         [5962.0776],
#         [5922.4927],
#         [6017.2534],
#         [5990.8071],
#         [6197.8960],
#         [6044.3188],
#         [6070.0381],
#         [6006.3379],
#         [5977.2373],
#         [6110.2065],
#         [6128.7817],
#         [6057.3877],
#         [6082.0825],
#         [6067.3047]])
# mu norms tensor(50.) 50
# sparsity tensor([0.0232, 0.0218, 0.0193, 0.0201, 0.0161, 0.0145, 0.0145, 0.0144, 0.0143,
#         0.0168, 0.0146, 0.0156, 0.0170, 0.0217, 0.0277, 0.0278, 0.0352, 0.0318,
#         0.0347, 0.0403, 0.0510, 0.0572, 0.0499, 0.0536, 0.0603, 0.0580, 0.0567,
#         0.0501, 0.0450, 0.0512, 0.0598, 0.0522, 0.0471, 0.0458, 0.0409, 0.0332,
#         0.0343, 0.0276, 0.0304, 0.0250, 0.0213, 0.0177, 0.0160, 0.0155, 0.0145,
#         0.0145, 0.0142, 0.0143, 0.0144, 0.0140])
# sparsitymean tensor(0.0305)
# pi sums tensor(42499.) 42499
# log likelihood tensor(51063.5039)
# cosine similarity tensor(0.1731)
# perplexity tensor(-51097.1289)
#
# likable inventor runaway sneer stamp nationalism investing wiretap mound baggage
# hassan howell music eco animate eugene islands chocolate cycle dupont
# sarah snapshot disturbing wen feather artistry plume populist corral anthology
# grizzly desperation nate televise greece librarian salvation longest ash steinberg
# deficiency warmth farrell whitman professionalism railway unsafe diversion misery devise
# undated new generous nacogdoches walled ready roman bowl training manipulate
# infamous dangerous spearhead alexandria sturdy mcgwire russa forthcoming program player
# undated christi costas view preside wound jenin donor fierce weis
# internet stock teaching major revolve track incursion joseph percent clinton
# say percent new year clinton sale news city home bush
# film movie new time say undated american work war play
# say game undated term bill world bond drug market state
# say percent year new rate people tax bank york million
# say new year people news woman time work york like
# say year percent company share new stock market time high
# say year new bush state percent news game health come
# say percent year new stock people company bank clinton game
# say year new percent company game clinton president news city
# say year company percent new people state million use stock
# say year game new york team news percent time play
# say year new percent million company people bank rate like
# say year company new million news percent people share stock
# say company new year percent york people work clinton know
# say year game new people company time like percent team
# say year company new government play percent people like game
# say percent year company million new stock share rise bush
# say percent year company new game rise fall rate share
# say year new news state time percent million game company
# say year percent new game million rise bush school company
# say year percent people new company time work state like
# say percent company year new state million stock rise people
# say year million new game percent state play company fall
# say year new company game play people day time know
# say game year new company team win time want season
# say year percent game new company rise share atlanta play
# say year percent stock market new company play party like
# say year game company computer percent play share new billion
# say new game company city year man million week run
# say percent company year play game time new quarter stock
# say percent use service company year boat win new billion
# say percent company year official game dress american know home
# say percent year washington million vocabulary baltimore right company visitor
# say court include bc game food service japan president rehnquist
# say year company yard share percent black bank spill veteran
# say percent game plant bankruptcy monday reclaim premiere gram bank
# say million caution dole fourth golf lobbyist shine endanger bash
# bc share latino adhere fragrance invade union say fund agree
# say dave surrogate mccourt sandler rebuilding think purge stay verizon
# share thrilling company tina million charge file alteration forward bank
# say percent milk mcconnell verizon million solomon alberta effort auctioneer
#
#
# current iteration: 100
# kappa mean tensor(11178.4424)
# kappas tensor([[11697.1768],
#         [10462.0479],
#         [ 9325.4639],
#         [ 9052.7793],
#         [ 9326.7510],
#         [ 9639.2500],
#         [10594.1621],
#         [11111.7490],
#         [14396.7080],
#         [11250.0889],
#         [10544.4648],
#         [13593.7812],
#         [12008.8662],
#         [12248.1201],
#         [10983.3877],
#         [13358.7002],
#         [16455.6797],
#         [13205.6611],
#         [11969.1982],
#         [11934.5371],
#         [16108.3887],
#         [15159.5859],
#         [10755.6494],
#         [10785.6123],
#         [10708.6279],
#         [16494.8887],
#         [13547.0225],
#         [11614.8008],
#         [12632.4854],
#         [10696.3271],
#         [12003.1387],
#         [12372.6152],
#         [10400.9102],
#         [11418.5596],
#         [ 9389.8457],
#         [ 9563.0420],
#         [10051.5264],
#         [ 9900.7402],
#         [10467.3574],
#         [ 9527.7764],
#         [10630.9111],
#         [ 9416.2832],
#         [11147.7188],
#         [10247.9404],
#         [ 8508.0820],
#         [ 8874.6299],
#         [ 8744.5859],
#         [ 8889.2744],
#         [ 8030.9604],
#         [ 7674.2886]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3619, 0.1378, 0.2080, 0.2577, 0.2805, 0.2832, 0.2465, 0.4008, 0.6406,
#         0.2025, 0.4233, 0.4250, 0.3364, 0.1927, 0.4571, 0.5484, 0.2726, 0.5169,
#         0.2467, 0.3643, 0.4431, 0.2527, 0.2419, 0.2602, 0.1402, 0.3092, 0.2339,
#         0.4494, 0.4776, 0.4131, 0.5223, 0.3152, 0.2472, 0.2032, 0.2040, 0.1636,
#         0.2414, 0.3045, 0.3530, 0.3421, 0.2410, 0.2342, 0.3644, 0.5459, 0.4344,
#         0.2736, 0.5339, 0.1184, 0.1202, 0.1620])
# sparsitymean tensor(0.3190)
# pi sums tensor(42499.) 42499
# log likelihood tensor(51985.0898)
# cosine similarity tensor(0.3520)
# perplexity tensor(-51355.3047)
#
#
# current iteration: 200
# kappa mean tensor(13197.0234)
# kappas tensor([[14804.3232],
#         [12029.3291],
#         [10711.0342],
#         [10383.7568],
#         [10609.6592],
#         [11318.3955],
#         [12137.6475],
#         [13102.8379],
#         [18139.8359],
#         [13311.9941],
#         [12125.8975],
#         [15954.9854],
#         [14294.2881],
#         [14540.2344],
#         [12785.1855],
#         [15759.2197],
#         [19608.1934],
#         [15539.8633],
#         [13856.0898],
#         [13625.5322],
#         [19288.3340],
#         [17957.5449],
#         [12434.4814],
#         [12731.3262],
#         [12540.6348],
#         [19321.3965],
#         [16373.6465],
#         [13531.5645],
#         [14985.0166],
#         [12426.3242],
#         [14228.1699],
#         [14468.5225],
#         [12151.8223],
#         [13038.4111],
#         [10812.5557],
#         [11084.9756],
#         [12630.3193],
#         [11698.2188],
#         [12447.2666],
#         [11059.1729],
#         [12627.4902],
#         [10824.5059],
#         [13170.9795],
#         [12984.8418],
#         [10042.1787],
#         [10559.6113],
#         [10543.8496],
#         [10290.8643],
#         [ 9513.5752],
#         [ 9445.2705]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3559, 0.1278, 0.2008, 0.2554, 0.2963, 0.2919, 0.1614, 0.3837, 0.5884,
#         0.2023, 0.4390, 0.4686, 0.3461, 0.1927, 0.4599, 0.6049, 0.2878, 0.5268,
#         0.3420, 0.3974, 0.4506, 0.2532, 0.2694, 0.2629, 0.1233, 0.3255, 0.2461,
#         0.4765, 0.4999, 0.3577, 0.5380, 0.3052, 0.2503, 0.2785, 0.2070, 0.1589,
#         0.3917, 0.2046, 0.2632, 0.3382, 0.2840, 0.2271, 0.3696, 0.7011, 0.4871,
#         0.3107, 0.3039, 0.0933, 0.1099, 0.1645])
# sparsitymean tensor(0.3236)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52024.8789)
# cosine similarity tensor(0.3555)
# perplexity tensor(-51375.9570)
#
#
# current iteration: 300
# kappa mean tensor(14489.5684)
# kappas tensor([[17024.2441],
#         [12925.3633],
#         [11531.3740],
#         [11231.9092],
#         [11364.1045],
#         [12427.1357],
#         [12898.3730],
#         [14321.4316],
#         [20588.3516],
#         [14660.3477],
#         [13083.8379],
#         [17422.5332],
#         [15781.7910],
#         [16087.4131],
#         [13907.3926],
#         [17195.4844],
#         [21606.4355],
#         [16959.8770],
#         [15030.0361],
#         [14682.0234],
#         [21276.0898],
#         [19595.1914],
#         [13532.1768],
#         [14097.4639],
#         [13889.7617],
#         [21147.7500],
#         [18139.6504],
#         [14710.5322],
#         [16493.8145],
#         [13560.8477],
#         [15588.3311],
#         [15697.0713],
#         [13198.3428],
#         [14006.5898],
#         [11705.7275],
#         [12037.4404],
#         [14555.0215],
#         [12831.1162],
#         [13539.4961],
#         [12026.6377],
#         [13891.1289],
#         [11713.2334],
#         [14406.5479],
#         [14660.1602],
#         [10931.3906],
#         [11550.1895],
#         [12226.5420],
#         [11368.6172],
#         [10568.7002],
#         [10803.4492]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3466, 0.1353, 0.2079, 0.2618, 0.2767, 0.2889, 0.2081, 0.3558, 0.6538,
#         0.1946, 0.4685, 0.4512, 0.3525, 0.2050, 0.4846, 0.6064, 0.2968, 0.5362,
#         0.3687, 0.4438, 0.4504, 0.2430, 0.3253, 0.2660, 0.1253, 0.3186, 0.2505,
#         0.4373, 0.4959, 0.3518, 0.5807, 0.3247, 0.2527, 0.3198, 0.2139, 0.1755,
#         0.3926, 0.2092, 0.2630, 0.3746, 0.2828, 0.2478, 0.3579, 0.7311, 0.4621,
#         0.3293, 0.2966, 0.0820, 0.1072, 0.1605])
# sparsitymean tensor(0.3314)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52042.5195)
# cosine similarity tensor(0.3567)
# perplexity tensor(-51388.2344)
#
#
# current iteration: 400
# kappa mean tensor(15447.4619)
# kappas tensor([[18733.4727],
#         [13610.1064],
#         [12102.4844],
#         [11802.6279],
#         [11930.0459],
#         [13237.7334],
#         [13458.3291],
#         [15220.9111],
#         [22458.5117],
#         [15643.1094],
#         [13776.0283],
#         [18463.6875],
#         [16893.6660],
#         [17201.9551],
#         [14697.6182],
#         [18276.6523],
#         [23128.1426],
#         [18022.8750],
#         [15840.6475],
#         [15493.5957],
#         [22764.5527],
#         [20788.9863],
#         [14306.8018],
#         [15108.8008],
#         [14953.4678],
#         [22486.4766],
#         [19486.2246],
#         [15614.4824],
#         [17585.1016],
#         [14454.1191],
#         [16602.8945],
#         [16596.1914],
#         [14029.6494],
#         [14692.8428],
#         [12393.4189],
#         [12750.5889],
#         [15954.7939],
#         [13585.9297],
#         [14286.7930],
#         [12728.3223],
#         [14828.1123],
#         [12355.0713],
#         [15373.0635],
#         [15882.1943],
#         [11580.6787],
#         [12275.8740],
#         [13380.7012],
#         [12238.5264],
#         [11394.8477],
#         [11901.4219]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3785, 0.1385, 0.2052, 0.2673, 0.2725, 0.3722, 0.2073, 0.3336, 0.6846,
#         0.2021, 0.4254, 0.4496, 0.3491, 0.2231, 0.4822, 0.6012, 0.3064, 0.5541,
#         0.3553, 0.4469, 0.4567, 0.2497, 0.3050, 0.2573, 0.1112, 0.3248, 0.2547,
#         0.4539, 0.4175, 0.3214, 0.5954, 0.3141, 0.2394, 0.3171, 0.2099, 0.1787,
#         0.3903, 0.2071, 0.2891, 0.3760, 0.2810, 0.2204, 0.3518, 0.7312, 0.4849,
#         0.3555, 0.3010, 0.0831, 0.1028, 0.1654])
# sparsitymean tensor(0.3320)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52052.0469)
# cosine similarity tensor(0.3575)
# perplexity tensor(-51390.9414)
#
#
# current iteration: 500
# kappa mean tensor(16208.1172)
# kappas tensor([[20152.4648],
#         [14086.2129],
#         [12539.5820],
#         [12274.6035],
#         [12354.2041],
#         [13914.9629],
#         [13888.6514],
#         [15915.6826],
#         [23952.7402],
#         [16371.4346],
#         [14314.4502],
#         [19313.4922],
#         [17736.2812],
#         [18075.8398],
#         [15348.1172],
#         [19093.8203],
#         [24383.7559],
#         [18858.7383],
#         [16485.1328],
#         [16115.5146],
#         [23959.2520],
#         [21714.9277],
#         [14892.2227],
#         [15920.5264],
#         [16394.9082],
#         [23573.4746],
#         [20577.4980],
#         [16252.8643],
#         [18399.5508],
#         [15111.9658],
#         [17398.8125],
#         [17289.1270],
#         [14571.8975],
#         [15212.5049],
#         [12926.7021],
#         [13255.3652],
#         [17061.7324],
#         [14180.1387],
#         [14896.0391],
#         [13242.6133],
#         [15567.2939],
#         [12887.0605],
#         [16140.3789],
#         [16858.8828],
#         [12087.5361],
#         [12832.5645],
#         [14216.2217],
#         [12989.2832],
#         [12027.7412],
#         [12791.1094]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3688, 0.1447, 0.2100, 0.2678, 0.2861, 0.2808, 0.1881, 0.3055, 0.6967,
#         0.1994, 0.4400, 0.4495, 0.3556, 0.2246, 0.4410, 0.6033, 0.4633, 0.5340,
#         0.3573, 0.4563, 0.4609, 0.2392, 0.3111, 0.2638, 0.3130, 0.3301, 0.2574,
#         0.4506, 0.5318, 0.3429, 0.5830, 0.3225, 0.2001, 0.3247, 0.2150, 0.1589,
#         0.3802, 0.2044, 0.2759, 0.3750, 0.2656, 0.2410, 0.3524, 0.7180, 0.4767,
#         0.3488, 0.2907, 0.0905, 0.1099, 0.1674])
# sparsitymean tensor(0.3375)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52061.1250)
# cosine similarity tensor(0.3579)
# perplexity tensor(-51394.3906)
#
#
# current iteration: 600
# kappa mean tensor(16832.2266)
# kappas tensor([[21365.6699],
#         [14472.8828],
#         [12873.7832],
#         [12618.4150],
#         [12683.0293],
#         [14473.1875],
#         [14217.1738],
#         [16487.0000],
#         [25243.5859],
#         [16974.1016],
#         [14744.3018],
#         [19969.1680],
#         [18454.9219],
#         [18797.5898],
#         [15937.6807],
#         [19739.6777],
#         [25326.3223],
#         [19551.2871],
#         [16964.3633],
#         [16613.3164],
#         [24942.5938],
#         [22452.1777],
#         [15371.0840],
#         [16561.2461],
#         [17944.8320],
#         [24503.7695],
#         [21438.8320],
#         [16792.6289],
#         [19084.1543],
#         [15670.2305],
#         [18028.3086],
#         [17835.7070],
#         [14972.4512],
#         [15623.0361],
#         [13327.6055],
#         [13747.3145],
#         [17897.7324],
#         [14619.5391],
#         [15327.4463],
#         [13669.8545],
#         [16217.2676],
#         [13257.9248],
#         [16739.2070],
#         [17643.4551],
#         [12485.9082],
#         [13245.4951],
#         [14908.0205],
#         [13660.9023],
#         [12593.4443],
#         [13541.6914]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3594, 0.1440, 0.2199, 0.2605, 0.2975, 0.2749, 0.2037, 0.3267, 0.6764,
#         0.2014, 0.4358, 0.4666, 0.3604, 0.2606, 0.4330, 0.6507, 0.4837, 0.5308,
#         0.3576, 0.4454, 0.5232, 0.2442, 0.2704, 0.2639, 0.3278, 0.3398, 0.2548,
#         0.4667, 0.4933, 0.3346, 0.6044, 0.3291, 0.1929, 0.3517, 0.2116, 0.1517,
#         0.3844, 0.1901, 0.2826, 0.3734, 0.3072, 0.2393, 0.3500, 0.7297, 0.4831,
#         0.3539, 0.2838, 0.0885, 0.1064, 0.1746])
# sparsitymean tensor(0.3419)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52066.2695)
# cosine similarity tensor(0.3581)
# perplexity tensor(-51396.2617)
#
#
# current iteration: 700
# kappa mean tensor(17362.3438)
# kappas tensor([[22417.6777],
#         [14764.2412],
#         [13164.6592],
#         [12892.7236],
#         [12967.1904],
#         [14966.3955],
#         [14483.7939],
#         [16985.7324],
#         [26358.3574],
#         [17473.7090],
#         [15042.6553],
#         [20545.5977],
#         [19058.2949],
#         [19388.6719],
#         [16418.2266],
#         [20326.1113],
#         [26106.9160],
#         [20136.7871],
#         [17404.4082],
#         [17073.2930],
#         [25803.3848],
#         [23071.7266],
#         [15713.2793],
#         [17081.0547],
#         [19215.8652],
#         [25302.5332],
#         [22194.8398],
#         [17231.4785],
#         [19683.7891],
#         [16141.0410],
#         [18582.5977],
#         [18282.3340],
#         [15376.8740],
#         [15960.3545],
#         [13665.0859],
#         [14143.3672],
#         [18594.5410],
#         [14991.1973],
#         [15691.2793],
#         [14059.6865],
#         [16755.5098],
#         [13577.3193],
#         [17265.2031],
#         [18286.2520],
#         [12830.1973],
#         [13573.5576],
#         [15477.3398],
#         [14265.7461],
#         [13087.3750],
#         [14237.0342]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3823, 0.1407, 0.1954, 0.2810, 0.2939, 0.2774, 0.2183, 0.3429, 0.6966,
#         0.2105, 0.4613, 0.4615, 0.3559, 0.2547, 0.4528, 0.6219, 0.4996, 0.5171,
#         0.3740, 0.4482, 0.4851, 0.2511, 0.2721, 0.2485, 0.3219, 0.3246, 0.2562,
#         0.4492, 0.5659, 0.3116, 0.5962, 0.3098, 0.1844, 0.3361, 0.2101, 0.1444,
#         0.3803, 0.1906, 0.2812, 0.3509, 0.3254, 0.2282, 0.3404, 0.7166, 0.4454,
#         0.3732, 0.2821, 0.0884, 0.1377, 0.1771])
# sparsitymean tensor(0.3414)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52070.4688)
# cosine similarity tensor(0.3584)
# perplexity tensor(-51397.9023)
#
#
# current iteration: 800
# kappa mean tensor(17821.8418)
# kappas tensor([[23285.2930],
#         [15004.7227],
#         [13389.1016],
#         [13121.8232],
#         [13183.9863],
#         [15474.2119],
#         [14711.4658],
#         [17392.4141],
#         [27364.8848],
#         [17934.2344],
#         [15364.5215],
#         [21030.6602],
#         [19623.9004],
#         [19865.7949],
#         [16801.1191],
#         [20800.5879],
#         [26774.9785],
#         [20647.5156],
#         [17780.7832],
#         [17479.4395],
#         [26515.1016],
#         [23615.1660],
#         [16005.1514],
#         [17529.2363],
#         [20292.0762],
#         [25974.8516],
#         [22805.1387],
#         [17592.1621],
#         [20210.4336],
#         [16547.0801],
#         [19022.7578],
#         [18656.9668],
#         [15746.8516],
#         [16284.5840],
#         [13960.1094],
#         [14596.8887],
#         [19222.9238],
#         [15326.9961],
#         [16016.4688],
#         [14349.3164],
#         [17257.1895],
#         [13824.3096],
#         [17750.8984],
#         [18850.1836],
#         [13110.6768],
#         [13892.2227],
#         [15983.8408],
#         [14736.1064],
#         [13566.8350],
#         [14818.2266]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3659, 0.1445, 0.1937, 0.2587, 0.3073, 0.2527, 0.1932, 0.3239, 0.7316,
#         0.1957, 0.4355, 0.4883, 0.3561, 0.2984, 0.4526, 0.6199, 0.4878, 0.5419,
#         0.3585, 0.4467, 0.4870, 0.2452, 0.2203, 0.2510, 0.2938, 0.3365, 0.2580,
#         0.4532, 0.5746, 0.3384, 0.6158, 0.3252, 0.2175, 0.3474, 0.2073, 0.1915,
#         0.3710, 0.2045, 0.2754, 0.3961, 0.3011, 0.2278, 0.3430, 0.7211, 0.4474,
#         0.3576, 0.2852, 0.0812, 0.2871, 0.2030])
# sparsitymean tensor(0.3463)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52074.4805)
# cosine similarity tensor(0.3585)
# perplexity tensor(-51398.0234)
#
#
# current iteration: 900
# kappa mean tensor(18228.6035)
# kappas tensor([[24086.5000],
#         [15217.4219],
#         [13620.3896],
#         [13353.7432],
#         [13405.5332],
#         [15925.4541],
#         [14928.8008],
#         [17774.3555],
#         [28269.8086],
#         [18343.5332],
#         [15626.7930],
#         [21426.3359],
#         [20104.6797],
#         [20294.3398],
#         [17137.8105],
#         [21220.4766],
#         [27376.1113],
#         [21102.8789],
#         [18079.3184],
#         [17810.7715],
#         [27187.0156],
#         [24077.0938],
#         [16294.6299],
#         [17933.5898],
#         [21211.9551],
#         [26564.6211],
#         [23357.1484],
#         [17928.3555],
#         [20618.9980],
#         [16894.6094],
#         [19442.6328],
#         [18977.7910],
#         [16087.3271],
#         [16537.0625],
#         [14155.1133],
#         [15177.2129],
#         [19734.4375],
#         [15645.6611],
#         [16258.4844],
#         [14616.7236],
#         [17678.5547],
#         [14096.5273],
#         [18113.1758],
#         [19348.1914],
#         [13324.9326],
#         [14159.1465],
#         [16377.8057],
#         [15104.7393],
#         [14081.4609],
#         [15340.1504]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3842, 0.1397, 0.2163, 0.2618, 0.2774, 0.2250, 0.2021, 0.3412, 0.7340,
#         0.1968, 0.4693, 0.4881, 0.3561, 0.3330, 0.4374, 0.6513, 0.5032, 0.5444,
#         0.3680, 0.4305, 0.4968, 0.2453, 0.2445, 0.2533, 0.3313, 0.3375, 0.2473,
#         0.4707, 0.5093, 0.3312, 0.6194, 0.3250, 0.2740, 0.3809, 0.2168, 0.3637,
#         0.3621, 0.1888, 0.2807, 0.3774, 0.3178, 0.2407, 0.3291, 0.7378, 0.4224,
#         0.3419, 0.2879, 0.0849, 0.3314, 0.1872])
# sparsitymean tensor(0.3539)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52078.5078)
# cosine similarity tensor(0.3587)
# perplexity tensor(-51400.3633)
#
#
# current iteration: 1000
# kappa mean tensor(18587.9512)
# kappas tensor([[24777.6094],
#         [15400.0703],
#         [13792.5391],
#         [13549.6895],
#         [13601.8086],
#         [16354.7363],
#         [15081.7334],
#         [18106.4121],
#         [29114.6895],
#         [18714.3867],
#         [15840.7900],
#         [21781.4297],
#         [20533.3438],
#         [20531.2832],
#         [17437.3750],
#         [21578.7402],
#         [27899.9492],
#         [21489.0156],
#         [18368.5957],
#         [18080.2832],
#         [27762.5996],
#         [24520.2480],
#         [16552.5156],
#         [18298.6836],
#         [21999.0566],
#         [27061.8711],
#         [23855.1426],
#         [18239.9023],
#         [20994.9082],
#         [17192.0684],
#         [19810.7539],
#         [19254.0352],
#         [16342.1895],
#         [16787.3828],
#         [14355.1123],
#         [15887.5742],
#         [20218.0977],
#         [15909.6973],
#         [16477.9980],
#         [14842.3926],
#         [18055.1523],
#         [14283.2891],
#         [18427.8984],
#         [19784.3164],
#         [13522.9902],
#         [14417.7344],
#         [16734.9102],
#         [15445.4209],
#         [14535.5469],
#         [15793.6348]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3589, 0.1481, 0.2269, 0.2769, 0.2913, 0.2174, 0.2089, 0.3071, 0.6928,
#         0.1906, 0.4523, 0.4753, 0.3633, 0.4077, 0.4188, 0.5969, 0.5448, 0.5542,
#         0.3943, 0.4196, 0.5033, 0.2466, 0.2426, 0.2610, 0.3095, 0.3412, 0.2542,
#         0.4566, 0.5462, 0.3079, 0.5966, 0.3154, 0.2877, 0.3513, 0.2057, 0.4556,
#         0.3825, 0.1946, 0.2730, 0.3531, 0.3485, 0.2415, 0.3194, 0.7262, 0.4281,
#         0.3355, 0.2805, 0.0988, 0.3130, 0.1310])
# sparsitymean tensor(0.3531)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52081.9648)
# cosine similarity tensor(0.3590)
# perplexity tensor(-51394.9258)
#
# en el la que lo del para como se una
# cup teaspoon tablespoon pepper cook salt minute heat butter recipe
# woods golf tournament tour par hole play pga round win
# race horse win cup derby finish racing olympic trainer earnhardt
# music song album band rock sing sound jazz musical pop
# woman book man life write black war novel author world
# lakers point neal game nba bryant coach laker jackson guard
# iraq saddam iraqi weapon war united hussein military nuclear states
# bc nyt bloom graphic map locator tk chart weekly graphics
# party vote republican election campaign dole voter candidate democratic senate
# film movie star actor character hollywood theater play director studio
# undated column word boston story news globe review service category
# york new times photo news city service clr fax client
# child parent family kid mother care home welfare father school
# china chinese hong kong taiwan beijing trade government united jiang
# bush gore kerry president campaign mccain say george florida texas
# bond yield rate percent basis investor treasury point benchmark debt
# clinton president house white dole lewinsky senate starr congress republican
# microsoft computer software windows system apple pc internet technology program
# game goal play kings team season score hockey puck defenseman
# yen dollar japan japanese currency trader bank mark rise rate
# atlanta news constitution cox journal coxnet moved coxnews service budget
# drug patient health doctor medical care study disease hospital cancer
# player team league season coach baseball football year owner nfl
# percent rate inflation economy growth fed economist rise increase price
# stock index rise share fall corp percent market amp dow
# million share quarter percent sale earnings cent profit rise billion
# school student education teacher college university district say class high
# tax budget cut billion income bill spending congress plan government
# police officer say city arrest crime official department drug charge
# fund investor stock investment money market mutual fidelity asset invest
# israeli israel palestinian arafat palestinians israelis peace gaza netanyahu sharon
# nato kosovo milosevic war serb albanian troops serbian bosnia military
# dodgers pitch hit inning run game innings season homer bat
# network cable television nbc cbs fox tv abc news channel
# say ms think people know like tell want thing feel
# company say business executive employee industry worker firm market job
# sox yankee game pitch run yankees series red baseball hit
# yard game touchdown cowboys quarterback play pass receiver coach bowl
# car vehicle ford truck gm driver drive wheel model engine
# cent oil price barrel bushel crude gas pound crop wheat
# airline flight plane air passenger pilot boeing airport delta fly
# court case judge law lawyer justice supreme state federal attorney
# bank loan banking billion financial say credit rate central asset
# church catholic priest religious bishop pope gay god christian say
# art museum artist painting gallery exhibition collection work ms building
# site internet web com www online mail information user page
# city water state area plant park building rain county river
# russia russian yeltsin moscow putin nuclear chechnya soviet government chechen
# peso sa file franc bolivar enron reai banco shareholder filed
#
#
# current iteration: 1100
# kappa mean tensor(18908.1875)
# kappas tensor([[25420.6934],
#         [15548.8037],
#         [13945.4600],
#         [13743.3359],
#         [13735.3994],
#         [16769.5723],
#         [15210.0752],
#         [18394.8281],
#         [29927.8945],
#         [19067.0176],
#         [16026.1768],
#         [22130.6367],
#         [20882.0254],
#         [20662.0000],
#         [17634.8145],
#         [21919.1836],
#         [28382.0605],
#         [21799.6309],
#         [18599.1445],
#         [18340.1758],
#         [28292.5352],
#         [24933.0195],
#         [16746.0078],
#         [18634.9883],
#         [22709.0566],
#         [27546.7676],
#         [24287.0430],
#         [18562.1602],
#         [21300.3926],
#         [17417.5332],
#         [20119.4160],
#         [19479.1211],
#         [16554.3086],
#         [16976.0430],
#         [14558.0156],
#         [16629.3535],
#         [20602.2051],
#         [16147.1426],
#         [16683.9688],
#         [15042.5479],
#         [18406.4824],
#         [14446.6406],
#         [18709.6719],
#         [20211.3164],
#         [13700.6240],
#         [14605.6982],
#         [17041.4902],
#         [15775.0146],
#         [14948.4746],
#         [16203.4043]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3652, 0.1400, 0.2252, 0.2748, 0.2965, 0.2081, 0.1851, 0.3288, 0.7111,
#         0.1933, 0.4758, 0.4889, 0.3647, 0.4745, 0.4668, 0.6329, 0.5429, 0.5627,
#         0.3603, 0.4509, 0.4562, 0.2527, 0.2803, 0.2550, 0.3197, 0.3410, 0.2520,
#         0.4629, 0.5157, 0.3058, 0.5766, 0.3242, 0.2821, 0.3109, 0.2129, 0.4163,
#         0.3775, 0.2031, 0.2825, 0.3609, 0.3001, 0.2253, 0.2924, 0.7240, 0.4257,
#         0.3268, 0.2888, 0.1056, 0.3177, 0.1060])
# sparsitymean tensor(0.3530)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52083.3398)
# cosine similarity tensor(0.3592)
# perplexity tensor(-51397.5742)
#
#
# current iteration: 1200
# kappa mean tensor(19196.0254)
# kappas tensor([[26009.5117],
#         [15688.1318],
#         [14073.2969],
#         [13892.0420],
#         [13858.7402],
#         [17102.3770],
#         [15351.3379],
#         [18642.6406],
#         [30652.7812],
#         [19393.2266],
#         [16197.3740],
#         [22421.1934],
#         [21239.3027],
#         [20731.5586],
#         [17853.3496],
#         [22243.9316],
#         [28833.2207],
#         [22078.2676],
#         [18791.4316],
#         [18580.3672],
#         [28784.8027],
#         [25271.2812],
#         [16920.7871],
#         [18900.4082],
#         [23366.1602],
#         [27960.6270],
#         [24648.7852],
#         [18790.8672],
#         [21611.7988],
#         [17673.4551],
#         [20420.6797],
#         [19697.4043],
#         [16720.7832],
#         [17169.5020],
#         [14719.9971],
#         [17313.8516],
#         [20953.9883],
#         [16320.3428],
#         [16905.4219],
#         [15212.5254],
#         [18723.1992],
#         [14608.0098],
#         [18956.6855],
#         [20539.3594],
#         [13879.4688],
#         [14812.0186],
#         [17291.9453],
#         [16069.8232],
#         [15325.3096],
#         [16597.8789]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3644, 0.1460, 0.2111, 0.2692, 0.2930, 0.1971, 0.2218, 0.3242, 0.7069,
#         0.1890, 0.4738, 0.4792, 0.3514, 0.4741, 0.4734, 0.6379, 0.5180, 0.5612,
#         0.4101, 0.4283, 0.5131, 0.2549, 0.2484, 0.2631, 0.3032, 0.3394, 0.2639,
#         0.4593, 0.5193, 0.3115, 0.5710, 0.3291, 0.2424, 0.3373, 0.2165, 0.3951,
#         0.3711, 0.2146, 0.2828, 0.3679, 0.3383, 0.2259, 0.3209, 0.7159, 0.4592,
#         0.3377, 0.2871, 0.1069, 0.2868, 0.0968])
# sparsitymean tensor(0.3542)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52085.9492)
# cosine similarity tensor(0.3593)
# perplexity tensor(-51397.7383)
#
#
# current iteration: 1300
# kappa mean tensor(19457.7695)
# kappas tensor([[26526.0312],
#         [15799.8379],
#         [14171.1035],
#         [14041.5244],
#         [13940.1230],
#         [17429.4746],
#         [15480.4219],
#         [18880.8066],
#         [31309.8281],
#         [19702.2969],
#         [16322.1162],
#         [22707.2129],
#         [21573.2305],
#         [20784.0156],
#         [18037.0762],
#         [22542.3887],
#         [29181.9688],
#         [22334.3223],
#         [19021.3828],
#         [18773.9980],
#         [29183.1289],
#         [25622.5625],
#         [17110.4629],
#         [19207.1953],
#         [23921.0332],
#         [28360.1387],
#         [24993.8477],
#         [19016.5645],
#         [21889.4863],
#         [17893.7891],
#         [20692.0020],
#         [19893.9844],
#         [16891.2812],
#         [17308.7012],
#         [14860.5986],
#         [17953.7949],
#         [21257.2812],
#         [16529.3711],
#         [17087.2715],
#         [15373.9521],
#         [19038.4980],
#         [14747.7119],
#         [19137.9824],
#         [20878.1484],
#         [13983.9688],
#         [14976.4834],
#         [17550.2168],
#         [16345.2559],
#         [15687.2266],
#         [16937.3750]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3740, 0.1393, 0.2106, 0.2775, 0.3070, 0.2214, 0.1942, 0.3014, 0.7100,
#         0.1881, 0.4516, 0.4955, 0.3574, 0.4709, 0.4783, 0.6420, 0.5294, 0.5614,
#         0.3786, 0.4720, 0.5132, 0.2519, 0.2352, 0.2450, 0.2938, 0.3253, 0.2507,
#         0.4485, 0.5695, 0.3186, 0.6170, 0.3277, 0.2610, 0.3763, 0.2161, 0.3786,
#         0.3827, 0.1907, 0.2823, 0.3479, 0.3530, 0.2390, 0.3154, 0.7390, 0.4517,
#         0.3662, 0.2854, 0.1115, 0.2142, 0.0928])
# sparsitymean tensor(0.3552)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52087.2500)
# cosine similarity tensor(0.3594)
# perplexity tensor(-51398.5703)
#
#
# current iteration: 1400
# kappa mean tensor(19691.8203)
# kappas tensor([[27024.7305],
#         [15926.2080],
#         [14250.4453],
#         [14176.2637],
#         [13998.5547],
#         [17727.3418],
#         [15560.0107],
#         [19063.0488],
#         [31873.8320],
#         [19978.8301],
#         [16461.2402],
#         [22963.6074],
#         [21885.3594],
#         [20860.9824],
#         [18179.8633],
#         [22810.6484],
#         [29543.4453],
#         [22575.7617],
#         [19175.2793],
#         [18944.3789],
#         [29577.5684],
#         [25911.7207],
#         [17261.7852],
#         [19418.0625],
#         [24418.5293],
#         [28704.1328],
#         [25365.6777],
#         [19189.2754],
#         [22171.6953],
#         [18092.9570],
#         [20916.5215],
#         [20053.9863],
#         [17064.9453],
#         [17469.0352],
#         [15003.9922],
#         [18492.1445],
#         [21551.6758],
#         [16648.3281],
#         [17242.3398],
#         [15553.5283],
#         [19271.5000],
#         [14887.0938],
#         [19309.3770],
#         [21181.6445],
#         [14068.1562],
#         [15112.3594],
#         [17776.1309],
#         [16605.8516],
#         [16039.4385],
#         [17251.6191]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3766, 0.1339, 0.2343, 0.2607, 0.3137, 0.2180, 0.1791, 0.3192, 0.6917,
#         0.1917, 0.4735, 0.5005, 0.3491, 0.5261, 0.4901, 0.6321, 0.5467, 0.5520,
#         0.3877, 0.4266, 0.4915, 0.2545, 0.2357, 0.2465, 0.3122, 0.3495, 0.2528,
#         0.4675, 0.5417, 0.2909, 0.5843, 0.3266, 0.2781, 0.3625, 0.2121, 0.3618,
#         0.3783, 0.1767, 0.2872, 0.3400, 0.3468, 0.2322, 0.3250, 0.7298, 0.4420,
#         0.3434, 0.2929, 0.1146, 0.1575, 0.0906])
# sparsitymean tensor(0.3526)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52088.8320)
# cosine similarity tensor(0.3596)
# perplexity tensor(-51396.0977)
#
#
# current iteration: 1500
# kappa mean tensor(19910.5371)
# kappas tensor([[27532.0957],
#         [16013.8057],
#         [14377.7002],
#         [14237.5342],
#         [14090.6934],
#         [17960.6250],
#         [15655.6904],
#         [19246.9570],
#         [32462.2109],
#         [20224.5781],
#         [16554.2617],
#         [23184.8105],
#         [22148.2422],
#         [20916.8984],
#         [18303.2441],
#         [23048.1270],
#         [29878.3184],
#         [22834.1348],
#         [19362.1504],
#         [19074.9922],
#         [29958.5371],
#         [26155.0371],
#         [17376.9473],
#         [19632.8262],
#         [24898.1758],
#         [29041.1523],
#         [25673.0332],
#         [19354.7305],
#         [22409.4844],
#         [18297.0430],
#         [21108.0586],
#         [20242.6094],
#         [17209.2617],
#         [17588.6055],
#         [15128.5098],
#         [18993.3887],
#         [21843.4648],
#         [16790.7812],
#         [17396.3750],
#         [15691.3330],
#         [19510.6152],
#         [15007.9395],
#         [19465.1973],
#         [21514.2715],
#         [14158.7021],
#         [15254.7803],
#         [17953.7871],
#         [16828.1055],
#         [16406.5078],
#         [17530.5605]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3643, 0.1384, 0.2097, 0.2663, 0.3124, 0.2279, 0.1954, 0.3392, 0.6900,
#         0.1942, 0.4700, 0.4932, 0.3526, 0.4771, 0.5013, 0.6313, 0.5288, 0.5642,
#         0.3759, 0.4784, 0.4795, 0.2480, 0.2448, 0.2556, 0.2899, 0.3375, 0.2529,
#         0.4639, 0.5498, 0.3228, 0.5913, 0.3236, 0.2687, 0.3516, 0.2083, 0.3644,
#         0.3764, 0.2075, 0.2668, 0.3494, 0.3365, 0.2356, 0.3156, 0.7382, 0.4412,
#         0.3427, 0.2994, 0.1102, 0.1347, 0.0897])
# sparsitymean tensor(0.3521)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52089.9375)
# cosine similarity tensor(0.3598)
# perplexity tensor(-51398.)
#
#
# current iteration: 1600
# kappa mean tensor(20114.7383)
# kappas tensor([[27960.3223],
#         [16137.7129],
#         [14486.2402],
#         [14356.1104],
#         [14163.0381],
#         [18165.9531],
#         [15748.4775],
#         [19405.1426],
#         [33019.1172],
#         [20457.5684],
#         [16659.5723],
#         [23366.6523],
#         [22390.3613],
#         [20965.6562],
#         [18428.7266],
#         [23240.8027],
#         [30194.0410],
#         [23050.5000],
#         [19524.6328],
#         [19224.9277],
#         [30334.4805],
#         [26418.6699],
#         [17482.5840],
#         [19819.7344],
#         [25373.7578],
#         [29363.5469],
#         [25966.9512],
#         [19492.3281],
#         [22615.9160],
#         [18493.7402],
#         [21290.6602],
#         [20386.0176],
#         [17321.3730],
#         [17704.0605],
#         [15268.7490],
#         [19451.1309],
#         [22115.5000],
#         [16922.9336],
#         [17506.3379],
#         [15824.8057],
#         [19708.3867],
#         [15109.5811],
#         [19612.5684],
#         [21774.5020],
#         [14255.2471],
#         [15341.7783],
#         [18160.1582],
#         [17105.0156],
#         [16766.8652],
#         [17804.0156]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3765, 0.1366, 0.1983, 0.2672, 0.3135, 0.2395, 0.1862, 0.2873, 0.6820,
#         0.1902, 0.4666, 0.4970, 0.3492, 0.5079, 0.5053, 0.6612, 0.5246, 0.5497,
#         0.3981, 0.4357, 0.5046, 0.2483, 0.2301, 0.2572, 0.2951, 0.3413, 0.2643,
#         0.4571, 0.5436, 0.2912, 0.6165, 0.3219, 0.2698, 0.3521, 0.2061, 0.3524,
#         0.3722, 0.2185, 0.2925, 0.3481, 0.3427, 0.2464, 0.3260, 0.7245, 0.4665,
#         0.3304, 0.2802, 0.1146, 0.1372, 0.0863])
# sparsitymean tensor(0.3522)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52090.4297)
# cosine similarity tensor(0.3597)
# perplexity tensor(-51397.5742)
#
#
# current iteration: 1700
# kappa mean tensor(20300.0820)
# kappas tensor([[28381.3711],
#         [16193.8037],
#         [14557.5898],
#         [14421.9004],
#         [14232.1797],
#         [18407.1348],
#         [15813.5166],
#         [19534.9922],
#         [33530.1719],
#         [20657.7852],
#         [16750.1621],
#         [23578.7012],
#         [22643.5430],
#         [21008.9531],
#         [18516.0137],
#         [23410.9102],
#         [30498.2754],
#         [23264.4297],
#         [19644.5254],
#         [19364.1523],
#         [30701.5996],
#         [26641.6113],
#         [17601.3301],
#         [19997.9043],
#         [25821.7676],
#         [29623.1855],
#         [26254.3711],
#         [19649.4219],
#         [22783.3535],
#         [18617.1191],
#         [21475.4141],
#         [20481.9160],
#         [17427.5645],
#         [17856.3359],
#         [15386.3643],
#         [19877.3496],
#         [22343.8848],
#         [17006.8945],
#         [17612.8594],
#         [15961.0381],
#         [19922.6621],
#         [15199.6123],
#         [19764.1484],
#         [21994.1289],
#         [14346.5498],
#         [15442.0186],
#         [18353.9238],
#         [17321.5020],
#         [17116.6504],
#         [18011.5176]])
# mu norms tensor(50.) 50
# sparsity tensor([0.3628, 0.1397, 0.2263, 0.2570, 0.3012, 0.2054, 0.2272, 0.3560, 0.7277,
#         0.1882, 0.4787, 0.4771, 0.3592, 0.5085, 0.4948, 0.6464, 0.5534, 0.5656,
#         0.3734, 0.4619, 0.5110, 0.2654, 0.2503, 0.2566, 0.2903, 0.3360, 0.2660,
#         0.4649, 0.5288, 0.2901, 0.6087, 0.3257, 0.2778, 0.3487, 0.2032, 0.3548,
#         0.3725, 0.2012, 0.2915, 0.3453, 0.3359, 0.2197, 0.3345, 0.7299, 0.4629,
#         0.3381, 0.2797, 0.1172, 0.1255, 0.0852])
# sparsitymean tensor(0.3546)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52091.9375)
# cosine similarity tensor(0.3598)
# perplexity tensor(-51395.9609)
#
#
# current iteration: 1800
# kappa mean tensor(20478.1504)
# kappas tensor([[28768.1445],
#         [16264.6611],
#         [14619.0674],
#         [14522.9922],
#         [14278.0332],
#         [18630.2422],
#         [15846.9668],
#         [19713.9902],
#         [34081.0625],
#         [20861.7520],
#         [16833.7578],
#         [23786.0840],
#         [22845.5254],
#         [21050.0078],
#         [18601.6465],
#         [23606.4434],
#         [30827.5215],
#         [23425.0918],
#         [19779.8340],
#         [19481.5723],
#         [31021.3730],
#         [26860.3008],
#         [17736.4219],
#         [20169.8848],
#         [26257.0684],
#         [29894.9648],
#         [26522.5430],
#         [19799.5898],
#         [22962.2656],
#         [18753.7695],
#         [21623.5176],
#         [20615.9707],
#         [17525.1992],
#         [17905.2422],
#         [15474.4336],
#         [20287.1328],
#         [22554.3828],
#         [17095.0996],
#         [17697.1973],
#         [16056.8682],
#         [20157.6758],
#         [15290.6348],
#         [19925.5840],
#         [22228.8887],
#         [14430.9385],
#         [15557.7744],
#         [18495.5059],
#         [17531.8223],
#         [17403.0957],
#         [18247.9766]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3443, 0.1449, 0.2045, 0.2639, 0.3107, 0.2082, 0.1975, 0.2991, 0.6945,
#         0.1926, 0.4774, 0.4848, 0.3516, 0.5024, 0.4903, 0.6612, 0.5503, 0.5769,
#         0.3829, 0.4509, 0.4710, 0.2598, 0.2423, 0.2542, 0.2904, 0.3514, 0.2470,
#         0.4659, 0.5574, 0.3048, 0.6468, 0.3221, 0.2220, 0.3468, 0.2035, 0.3714,
#         0.3686, 0.2103, 0.2836, 0.3665, 0.3240, 0.2356, 0.3265, 0.7217, 0.4674,
#         0.3302, 0.2853, 0.1174, 0.1716, 0.0860])
# sparsitymean tensor(0.3528)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52092.5039)
# cosine similarity tensor(0.3597)
# perplexity tensor(-51396.4727)
#
#
# current iteration: 1900
# kappa mean tensor(20644.3125)
# kappas tensor([[29166.7441],
#         [16335.0107],
#         [14676.2109],
#         [14567.9990],
#         [14322.8027],
#         [18854.4648],
#         [15898.1982],
#         [19852.9570],
#         [34570.0547],
#         [21003.8379],
#         [16922.3164],
#         [23959.9492],
#         [23029.1836],
#         [21113.1562],
#         [18698.3164],
#         [23762.2168],
#         [31109.7246],
#         [23597.9883],
#         [19910.2676],
#         [19615.0898],
#         [31293.7090],
#         [27061.9004],
#         [17861.5742],
#         [20300.9336],
#         [26623.4824],
#         [30157.4512],
#         [26776.1680],
#         [19909.1152],
#         [23115.8867],
#         [18911.8281],
#         [21775.0508],
#         [20778.4688],
#         [17612.4980],
#         [17992.1289],
#         [15554.6426],
#         [20656.1621],
#         [22767.4883],
#         [17215.8828],
#         [17810.1660],
#         [16171.3105],
#         [20329.5645],
#         [15385.6855],
#         [20049.0117],
#         [22439.7070],
#         [14493.2588],
#         [15647.2627],
#         [18638.2266],
#         [17733.7559],
#         [17713.5469],
#         [18473.2402]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3798, 0.1366, 0.2231, 0.2688, 0.2760, 0.1889, 0.1949, 0.2816, 0.7236,
#         0.1962, 0.4619, 0.4908, 0.3532, 0.4979, 0.4759, 0.5864, 0.5417, 0.5696,
#         0.3783, 0.4676, 0.5133, 0.2491, 0.2462, 0.2558, 0.2978, 0.3347, 0.2555,
#         0.4611, 0.4892, 0.2954, 0.5843, 0.3168, 0.2348, 0.3562, 0.1993, 0.3823,
#         0.3672, 0.2046, 0.2736, 0.3520, 0.3284, 0.2392, 0.3226, 0.7313, 0.4480,
#         0.3433, 0.2879, 0.1159, 0.3524, 0.0832])
# sparsitymean tensor(0.3523)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52093.9961)
# cosine similarity tensor(0.3599)
# perplexity tensor(-51395.6562)
#
#
# current iteration: 2000
# kappa mean tensor(20799.8125)
# kappas tensor([[29480.9512],
#         [16418.0254],
#         [14743.1035],
#         [14642.2256],
#         [14351.9727],
#         [19089.7363],
#         [15965.7646],
#         [20000.9824],
#         [35021.8320],
#         [21143.2773],
#         [16991.2988],
#         [24102.0840],
#         [23225.0020],
#         [21120.0039],
#         [18817.2070],
#         [23867.8574],
#         [31347.1152],
#         [23762.8613],
#         [20013.3379],
#         [19718.7871],
#         [31569.8008],
#         [27288.3926],
#         [17961.5762],
#         [20440.7578],
#         [26947.1543],
#         [30394.8828],
#         [26995.6289],
#         [20008.1367],
#         [23277.1836],
#         [19040.9004],
#         [21905.0801],
#         [20873.4082],
#         [17645.2188],
#         [18099.4434],
#         [15630.7441],
#         [21037.9961],
#         [23009.3281],
#         [17310.4062],
#         [17886.1895],
#         [16304.7119],
#         [20508.1211],
#         [15454.6641],
#         [20167.7715],
#         [22610.8945],
#         [14603.6602],
#         [15706.4902],
#         [18761.0781],
#         [17909.3008],
#         [18132.3457],
#         [18685.9375]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3775, 0.1309, 0.2208, 0.2574, 0.3000, 0.1845, 0.1856, 0.3207, 0.7508,
#         0.1969, 0.4687, 0.4912, 0.3624, 0.5001, 0.4214, 0.6367, 0.5126, 0.5634,
#         0.3626, 0.4489, 0.5015, 0.2658, 0.2591, 0.2461, 0.2805, 0.3438, 0.2562,
#         0.4382, 0.5302, 0.3006, 0.5938, 0.3384, 0.1996, 0.3925, 0.2031, 0.3955,
#         0.3582, 0.1872, 0.2961, 0.3474, 0.3171, 0.2351, 0.3288, 0.7193, 0.4284,
#         0.3271, 0.2919, 0.1158, 0.4290, 0.0827])
# sparsitymean tensor(0.3540)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52094.4414)
# cosine similarity tensor(0.3597)
# perplexity tensor(-51397.3398)
#
# en el que la lo para una se como del
# cup teaspoon tablespoon pepper cook salt gram minute recipe heat
# woods golf tournament tour par round hole pga play putt
# race horse win derby cup finish olympic racing track winner
# music song album band rock jazz sing singer sound record
# woman book man life write world black war novel author
# lakers point neal game bryant nba rebound coach laker guard
# iraq weapon iraqi saddam war united nuclear military states hussein
# bc nyt bloom bos map locator attn tk graphic ladn
# party vote republican election dole campaign voter candidate democratic senate
# film movie star actor character hollywood theater director play comedy
# undated column word boston story news review globe category photo
# york new times photo news service city fax clr client
# child parent family care mother kid welfare father health home
# china chinese hong kong beijing taiwan trade government nuclear united
# bush gore kerry president campaign mccain say george presidential texas
# bond yield basis rate percent treasury investor point benchmark year
# clinton president house white dole congress administration lewinsky republican senate
# microsoft computer software windows system apple internet pc netscape program
# game play goal kings team score season hockey defenseman shot
# yen dollar japan japanese currency trader bank mark tokyo rate
# atlanta news constitution journal cox coxnet moved coxnews service budget
# drug patient health doctor medical study care disease hospital dr
# player team league season coach baseball owner year football nfl
# percent rate inflation economy fed growth economist rise price increase
# stock index rise share fall corp percent amp market dow
# ...
# cosine similarity tensor(0.3603)
# perplexity tensor(-51387.1523)
#
#
# current iteration: 4400
# kappa mean tensor(22850.3652)
# kappas tensor([[34276.0547],
#         [16920.0977],
#         [15302.2549],
#         [15221.1533],
#         [14576.3223],
#         [22318.6328],
#         [16408.4082],
#         [21379.3477],
#         [42345.4336],
#         [23128.9844],
#         [17409.8516],
#         [26142.5703],
#         [25902.6191],
#         [21140.4023],
#         [19876.1133],
#         [25933.5840],
#         [34800.5664],
#         [25868.5859],
#         [21178.1777],
#         [21108.2207],
#         [35456.8047],
#         [30019.0781],
#         [18970.8203],
#         [22356.1562],
#         [31581.5449],
#         [33806.8320],
#         [30028.7285],
#         [21270.0742],
#         [25498.3926],
#         [20244.5664],
#         [23711.3086],
#         [22015.5840],
#         [18670.6250],
#         [18938.3730],
#         [16515.1367],
#         [25879.8125],
#         [25686.5137],
#         [18222.8945],
#         [18685.1895],
#         [17406.2988],
#         [22594.4785],
#         [16220.0117],
#         [21508.2539],
#         [25402.2793],
#         [18720.2832],
#         [16788.2656],
#         [20367.8945],
#         [19988.9434],
#         [23445.0879],
#         [21280.6699]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3648, 0.1430, 0.1980, 0.2782, 0.2858, 0.1731, 0.1926, 0.3622, 0.7375,
#         0.1870, 0.4544, 0.4807, 0.3437, 0.4685, 0.5090, 0.6616, 0.5211, 0.5626,
#         0.3925, 0.4531, 0.5368, 0.2546, 0.2522, 0.2507, 0.2898, 0.3385, 0.2523,
#         0.4502, 0.5380, 0.3147, 0.6202, 0.3397, 0.2773, 0.3554, 0.1998, 0.4904,
#         0.3983, 0.2079, 0.2742, 0.3311, 0.3123, 0.2212, 0.3214, 0.7319, 0.1290,
#         0.3070, 0.2852, 0.1269, 0.4842, 0.0697])
# sparsitymean tensor(0.3546)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52105.6562)
# cosine similarity tensor(0.3603)
# perplexity tensor(-51387.6289)
#
#
# current iteration: 4500
# kappa mean tensor(22899.2754)
# kappas tensor([[34387.6836],
#         [16910.1895],
#         [15347.6338],
#         [15242.7412],
#         [14565.5830],
#         [22358.9082],
#         [16389.6914],
#         [21388.9395],
#         [42568.8594],
#         [23161.2363],
#         [17400.6270],
#         [26204.2715],
#         [25991.2461],
#         [21127.8965],
#         [19856.3809],
#         [25987.8223],
#         [34894.3438],
#         [25914.9121],
#         [21218.0957],
#         [21135.7227],
#         [35552.6875],
#         [30101.6211],
#         [18997.2832],
#         [22430.1582],
#         [31718.4297],
#         [33890.3945],
#         [30137.8613],
#         [21301.5410],
#         [25542.8633],
#         [20268.6465],
#         [23753.5996],
#         [22047.6621],
#         [18667.2031],
#         [18956.1035],
#         [16544.4062],
#         [25990.2344],
#         [25733.8164],
#         [18226.8789],
#         [18718.3047],
#         [17425.6914],
#         [22669.9531],
#         [16230.6455],
#         [21512.0996],
#         [25491.2148],
#         [18849.8633],
#         [16799.3633],
#         [20379.6484],
#         [20051.8086],
#         [23593.3652],
#         [21327.5605]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3851, 0.1368, 0.2050, 0.2640, 0.2950, 0.1763, 0.1757, 0.3476, 0.7390,
#         0.1924, 0.4568, 0.4935, 0.3526, 0.4998, 0.4987, 0.6414, 0.5479, 0.5625,
#         0.4110, 0.4773, 0.5294, 0.2612, 0.2315, 0.2449, 0.2827, 0.3467, 0.2538,
#         0.4563, 0.5434, 0.3187, 0.5844, 0.3225, 0.2655, 0.3672, 0.2050, 0.4904,
#         0.3916, 0.2065, 0.2823, 0.3354, 0.3532, 0.2272, 0.3159, 0.7297, 0.1327,
#         0.3237, 0.2725, 0.1179, 0.4312, 0.0688])
# sparsitymean tensor(0.3550)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52105.8633)
# cosine similarity tensor(0.3602)
# perplexity tensor(-51386.1133)
#
#
# current iteration: 4600
# kappa mean tensor(22945.4297)
# kappas tensor([[34478.5312],
#         [16911.1797],
#         [15354.2686],
#         [15251.3174],
#         [14571.1055],
#         [22438.1621],
#         [16378.9121],
#         [21408.1836],
#         [42821.0039],
#         [23195.8594],
#         [17405.1914],
#         [26229.3730],
#         [26066.0898],
#         [21139.2578],
#         [19867.6445],
#         [26027.4883],
#         [34983.8438],
#         [25966.1895],
#         [21251.1543],
#         [21152.4609],
#         [35674.2383],
#         [30173.9707],
#         [19005.0605],
#         [22433.1504],
#         [31834.5957],
#         [33970.5586],
#         [30204.3594],
#         [21337.5762],
#         [25624.1230],
#         [20283.5215],
#         [23790.1230],
#         [22072.7676],
#         [18672.8613],
#         [18953.6660],
#         [16559.2598],
#         [26121.2480],
#         [25787.7793],
#         [18257.0508],
#         [18759.6660],
#         [17454.2832],
#         [22732.3789],
#         [16243.9355],
#         [21535.7578],
#         [25522.2246],
#         [18954.1445],
#         [16804.2773],
#         [20408.9297],
#         [20101.1875],
#         [23722.8750],
#         [21378.6895]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3748, 0.1404, 0.2151, 0.2808, 0.2910, 0.1708, 0.1956, 0.3275, 0.7579,
#         0.1885, 0.4757, 0.4949, 0.3534, 0.4879, 0.4909, 0.6708, 0.5570, 0.5863,
#         0.3971, 0.4671, 0.5058, 0.2575, 0.2413, 0.2550, 0.2820, 0.3429, 0.2566,
#         0.4684, 0.5489, 0.3191, 0.6089, 0.3349, 0.2705, 0.3561, 0.1904, 0.4881,
#         0.3900, 0.1955, 0.2868, 0.3434, 0.3222, 0.2343, 0.3105, 0.7434, 0.1289,
#         0.3346, 0.2768, 0.1212, 0.4515, 0.0681])
# sparsitymean tensor(0.3571)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52106.2734)
# cosine similarity tensor(0.3602)
# perplexity tensor(-51386.7266)
#
#
# current iteration: 4700
# kappa mean tensor(22985.4688)
# kappas tensor([[34585.2969],
#         [16937.8027],
#         [15331.8789],
#         [15274.7773],
#         [14572.3311],
#         [22442.5039],
#         [16366.6475],
#         [21393.5996],
#         [43024.4766],
#         [23250.0254],
#         [17402.1445],
#         [26272.7266],
#         [26114.4160],
#         [21125.8340],
#         [19894.9238],
#         [26052.1602],
#         [35092.5352],
#         [25979.0781],
#         [21299.9453],
#         [21163.9336],
#         [35759.7422],
#         [30257.3887],
#         [19010.0430],
#         [22469.6875],
#         [31955.4922],
#         [34047.5469],
#         [30259.7129],
#         [21385.2637],
#         [25664.4902],
#         [20299.8398],
#         [23823.0703],
#         [22076.5117],
#         [18691.3730],
#         [18953.6719],
#         [16573.8379],
#         [26240.2734],
#         [25817.4375],
#         [18279.8086],
#         [18755.2305],
#         [17479.8105],
#         [22797.5977],
#         [16274.1416],
#         [21549.9258],
#         [25571.9668],
#         [19066.4277],
#         [16823.6777],
#         [20426.9629],
#         [20149.0039],
#         [23808.3594],
#         [21428.1328]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3534, 0.1464, 0.2141, 0.2662, 0.3091, 0.1852, 0.1861, 0.3517, 0.7496,
#         0.1930, 0.4769, 0.4859, 0.3495, 0.4784, 0.4453, 0.6497, 0.5529, 0.5571,
#         0.3773, 0.4692, 0.5069, 0.2766, 0.2510, 0.2467, 0.3005, 0.3393, 0.2524,
#         0.4547, 0.5451, 0.3135, 0.6167, 0.3185, 0.2673, 0.3959, 0.2016, 0.4850,
#         0.3983, 0.1745, 0.2718, 0.3403, 0.3143, 0.2341, 0.3095, 0.7317, 0.1255,
#         0.3476, 0.2821, 0.1183, 0.4567, 0.0683])
# sparsitymean tensor(0.3548)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52105.8555)
# cosine similarity tensor(0.3603)
# perplexity tensor(-51385.0547)
#
#
# current iteration: 4800
# kappa mean tensor(23031.9375)
# kappas tensor([[34711.5898],
#         [16950.6055],
#         [15344.5205],
#         [15274.7275],
#         [14575.1348],
#         [22534.3105],
#         [16383.0576],
#         [21402.4727],
#         [43244.5977],
#         [23310.4531],
#         [17422.3379],
#         [26321.2227],
#         [26180.7656],
#         [21130.2949],
#         [19921.2891],
#         [26097.2129],
#         [35179.5430],
#         [26011.1074],
#         [21357.7441],
#         [21195.1816],
#         [35835.5156],
#         [30337.8906],
#         [19026.6211],
#         [22518.7207],
#         [32076.7812],
#         [34095.5156],
#         [30347.8340],
#         [21409.9082],
#         [25713.5566],
#         [20310.7754],
#         [23860.3320],
#         [22118.2598],
#         [18691.8926],
#         [18927.0938],
#         [16605.7324],
#         [26349.8027],
#         [25837.2598],
#         [18298.8262],
#         [18796.8105],
#         [17501.3633],
#         [22838.2988],
#         [16256.0361],
#         [21569.0801],
#         [25638.7266],
#         [19215.9980],
#         [16834.6348],
#         [20436.1680],
#         [20215.8594],
#         [23910.5137],
#         [21472.9238]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3628, 0.1310, 0.1963, 0.2598, 0.2917, 0.1740, 0.1909, 0.3579, 0.7535,
#         0.1892, 0.4785, 0.4818, 0.3426, 0.4899, 0.4869, 0.6498, 0.5514, 0.5627,
#         0.3867, 0.4661, 0.5450, 0.2538, 0.2457, 0.2505, 0.2920, 0.3483, 0.2593,
#         0.4650, 0.5466, 0.3276, 0.6137, 0.3233, 0.2632, 0.3804, 0.1957, 0.4917,
#         0.3930, 0.1859, 0.2660, 0.3347, 0.3395, 0.2316, 0.3235, 0.7527, 0.1223,
#         0.3271, 0.2805, 0.1219, 0.4931, 0.0683])
# sparsitymean tensor(0.3569)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52105.8008)
# cosine similarity tensor(0.3602)
# perplexity tensor(-51386.2344)
#
#
# current iteration: 4900
# kappa mean tensor(23074.9336)
# kappas tensor([[34825.6367],
#         [16961.7305],
#         [15317.4463],
#         [15291.6025],
#         [14535.4756],
#         [22570.8477],
#         [16379.6855],
#         [21429.1523],
#         [43451.9258],
#         [23357.8848],
#         [17398.8652],
#         [26356.6094],
#         [26275.2461],
#         [21113.8809],
#         [19940.6816],
#         [26134.6934],
#         [35246.7656],
#         [26049.7949],
#         [21390.8164],
#         [21235.4922],
#         [35917.5547],
#         [30405.6270],
#         [19043.9863],
#         [22558.6875],
#         [32213.7578],
#         [34176.7617],
#         [30428.5156],
#         [21464.8652],
#         [25773.4473],
#         [20321.2891],
#         [23868.2949],
#         [22160.4316],
#         [18671.1562],
#         [18934.5840],
#         [16623.5527],
#         [26475.1133],
#         [25878.8066],
#         [18346.8965],
#         [18813.5312],
#         [17505.4141],
#         [22883.0176],
#         [16269.9014],
#         [21616.0684],
#         [25719.1992],
#         [19342.9082],
#         [16856.3125],
#         [20443.1816],
#         [20247.3789],
#         [23981.0410],
#         [21541.2012]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3688, 0.1386, 0.2145, 0.2797, 0.2883, 0.1711, 0.1719, 0.3425, 0.7555,
#         0.1919, 0.4582, 0.5010, 0.3493, 0.4835, 0.4729, 0.6511, 0.5589, 0.5581,
#         0.3819, 0.4296, 0.5352, 0.2594, 0.2414, 0.2435, 0.2993, 0.3494, 0.2565,
#         0.4536, 0.5101, 0.3252, 0.6064, 0.3372, 0.2871, 0.3763, 0.2047, 0.4953,
#         0.3746, 0.1980, 0.2762, 0.3328, 0.3564, 0.2229, 0.3203, 0.7447, 0.1161,
#         0.3150, 0.2817, 0.1236, 0.4352, 0.0677])
# sparsitymean tensor(0.3543)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52106.6875)
# cosine similarity tensor(0.3603)
# perplexity tensor(-51383.3555)
#
#
# current iteration: 5000
# kappa mean tensor(23115.1543)
# kappas tensor([[34933.8828],
#         [16955.0801],
#         [15315.9014],
#         [15291.9482],
#         [14521.9834],
#         [22620.0176],
#         [16423.1328],
#         [21438.5176],
#         [43641.7422],
#         [23408.8633],
#         [17383.6113],
#         [26395.6875],
#         [26343.8008],
#         [21140.6699],
#         [19984.7422],
#         [26187.6152],
#         [35327.8086],
#         [26063.9473],
#         [21420.1387],
#         [21267.6680],
#         [35982.4023],
#         [30479.8516],
#         [19068.4883],
#         [22604.3848],
#         [32322.4238],
#         [34240.7930],
#         [30483.0586],
#         [21473.1172],
#         [25809.7578],
#         [20306.3125],
#         [23883.1230],
#         [22210.2324],
#         [18690.8770],
#         [18956.9824],
#         [16658.8203],
#         [26603.5449],
#         [25902.6641],
#         [18388.0137],
#         [18837.4961],
#         [17498.6680],
#         [22915.0469],
#         [16285.6445],
#         [21605.6816],
#         [25789.9922],
#         [19458.7520],
#         [16861.9473],
#         [20431.3555],
#         [20307.7207],
#         [24057.7617],
#         [21576.0527]])
# mu norms tensor(50.0000) 50
# sparsity tensor([0.3767, 0.1446, 0.1920, 0.2624, 0.3034, 0.1785, 0.2055, 0.3723, 0.7183,
#         0.1888, 0.4645, 0.4789, 0.3399, 0.4873, 0.5380, 0.6424, 0.5613, 0.5725,
#         0.3834, 0.4768, 0.5088, 0.2688, 0.2360, 0.2583, 0.2885, 0.3571, 0.2532,
#         0.4651, 0.5444, 0.3313, 0.6058, 0.3259, 0.2697, 0.3629, 0.2018, 0.4950,
#         0.3911, 0.1859, 0.2946, 0.3381, 0.3244, 0.2285, 0.3123, 0.7404, 0.1229,
#         0.3163, 0.2847, 0.1258, 0.4631, 0.0672])
# sparsitymean tensor(0.3571)
# pi sums tensor(42499.) 42499
# log likelihood tensor(52106.9844)
# cosine similarity tensor(0.3604)
# perplexity tensor(-51383.9648)
#
# en la el que lo una del por se para
# cup tablespoon teaspoon pepper salt recipe cook gram minute sauce
# golf woods tournament hole tour par play round pga putt
# race horse win derby cup racing olympic finish track winner
# music song album band rock sing record jazz musical singer
# woman book man life write black war novel world like
# lakers neal point game nba bryant rebound laker coach jackson
# iraq saddam iraqi weapon war military hussein united baghdad nuclear
# bc nyt bloom locator graphic map bos tk chart weekly
# vote party republican election dole campaign voter senate republicans candidate
# film movie star actor character hollywood theater play director scene
# undated column word boston story news globe moved service category
# york new times photo news service city fax nyt article
# child parent family mother kid care welfare home father school
# china chinese kong hong beijing taiwan trade united states jiang
# bush gore president campaign kerry mccain say texas cheney george
# bond yield rate investor basis treasury percent point benchmark year
# clinton president house white dole lewinsky starr administration congress senate
# microsoft computer software windows system apple pc internet netscape program
# game play goal kings team season score defenseman rangers shot
# yen dollar japan japanese currency bank trader mark franc rise
# atlanta news constitution journal cox coxnet moved coxnews service budget
# drug patient health doctor medical care study disease cancer hospital
# player team league season coach baseball year owner football million
# percent rate inflation fed economy growth economist rise price increase
# stock index rise share fall corp amp percent market dow
# million share quarter percent sale earnings cent profit billion rise
# school student education teacher college university district high say class
# tax budget cut billion income bill spending pay plan congress
# police officer say city arrest crime drug official charge man
# fund stock investor market investment money mutual portfolio percent invest
# israel palestinian israeli arafat palestinians peace israelis gaza arab netanyahu
# kosovo nato milosevic albanian serb bosnia war force serbian bosnian
# dodgers pitch inning hit run innings game homer season bat
# network cable nbc television cbs fox tv news abc channel
# say people think know like want tell thing day work
# company business say executive industry employee amp worker market sell
# sox yankee game pitch run baseball hit red inning yankees
# yard touchdown game quarterback cowboys play pass run receiver season
# car vehicle ford truck driver model drive auto chrysler engine
# cent oil price barrel bushel crude gas energy crop pound
# airline flight plane air passenger pilot airport boeing travel fly
# court case judge law lawyer state justice supreme federal appeal
# bank loan banking rate central financial billion credit lending say
# russia government russian country united yeltsin states minister union economic
# art museum painting artist gallery building collection ms exhibition work
# site internet web com www online mail information user http
# city state water county area plant park building california mayor
# peso sa percent mexico rise mexican company banco share fall
# church catholic lewinsky file bishop priest starr bolivar enron ms

# %% [markdown]
# # Get Topic Coherence

# %%
mu_final = mu_samples / num_samples
kappa_final = kappa_samples / num_samples
theta_final = theta_samples / num_samples
print("final perplexity", vmf_perplexity(tensor_te, mu_final, kappa_final, alpha, N=1000))
emb = mu_final.cpu().numpy()
topics = get_topics(emb, vocab)
print_summary(topics,method,dataset)

if dataset == '20news':
    pi = dist.StickBreakingTransform()(theta_final)
    pi = pi.cpu().numpy()
    clustering_metrics_20news(pi)
# Out:
# final perplexity tensor(-51383.1719)
#
# Method  = vptm
# Number of topics = 50
# Dataset = nytimes
#
#  NPMI       TU         Topic
#  0.28958    1.00000    en la el que lo una del por se para
#  0.07547    0.95000    cup tablespoon teaspoon pepper salt recipe cook gram minute sauce
#  0.18237    0.92500    golf woods tournament hole tour par play round pga putt
#  0.12772    0.95000    race horse win derby cup racing olympic finish track winner
#  0.17049    1.00000    music song album band rock sing record jazz musical singer
#  0.04249    0.83333    woman book man life write black war novel world like
#  0.11855    0.82000    lakers neal point game nba bryant rebound laker coach jackson
#  0.16175    0.86667    iraq saddam iraqi weapon war military hussein united baghdad nuclear
#  0.00792    0.95000    bc nyt bloom locator graphic map bos tk chart weekly
#  0.21569    0.85000    vote party republican election dole campaign voter senate republicans candidate
#  0.11964    0.92500    film movie star actor character hollywood theater play director scene
#  0.00888    0.80833    undated column word boston story news globe moved service category
#  0.08285    0.74167    york new times photo news service city fax nyt article
#  0.07727    0.90000    child parent family mother kid care welfare home father school
#  0.17102    0.88333    china chinese kong hong beijing taiwan trade united states jiang
#  0.12432    0.81667    bush gore president campaign kerry mccain say texas cheney george
#  0.02962    0.70000    bond yield rate investor basis treasury percent point benchmark year
#  0.11057    0.70000    clinton president house white dole lewinsky starr administration congress senate
#  0.16726    0.95000    microsoft computer software windows system apple pc internet netscape program
#  0.09342    0.72000    game play goal kings team season score defenseman rangers shot
#  0.07642    0.87000    yen dollar japan japanese currency bank trader mark franc rise
#  0.01436    0.75833    atlanta news constitution journal cox coxnet moved coxnews service budget
#  0.15603    0.90000    drug patient health doctor medical care study disease cancer hospital
#  0.12097    0.67500    player team league season coach baseball year owner football million
#  0.11667    0.72000    percent rate inflation fed economy growth economist rise price increase
#  0.08470    0.55333    stock index rise share fall corp amp percent market dow
#  0.10142    0.60333    million share quarter percent sale earnings cent profit billion rise
#  0.10610    0.86667    school student education teacher college university district high say class
#  0.11176    0.83333    tax budget cut billion income bill spending pay plan congress
#  0.04018    0.75000    police officer say city arrest crime drug official charge man
#  0.14460    0.75000    fund stock investor market investment money mutual portfolio percent invest
#  0.30158    1.00000    israel palestinian israeli arafat palestinians peace israelis gaza arab netanyahu
#  0.18538    0.93333    kosovo nato milosevic albanian serb bosnia war force serbian bosnian
#  0.17868    0.62833    dodgers pitch inning hit run innings game homer season bat
#  0.28941    0.92500    network cable nbc television cbs fox tv news abc channel
#  0.09554    0.81667    say people think know like want tell thing day work
#  0.03331    0.75000    company business say executive industry employee amp worker market sell
#  0.18208    0.65333    sox yankee game pitch run baseball hit red inning yankees
#  0.20430    0.70333    yard touchdown game quarterback cowboys play pass run receiver season
#  0.18439    1.00000    car vehicle ford truck driver model drive auto chrysler engine
#  0.09534    0.90000    cent oil price barrel bushel crude gas energy crop pound
#  0.17492    1.00000    airline flight plane air passenger pilot airport boeing travel fly
#  0.19152    0.95000    court case judge law lawyer state justice supreme federal appeal
#  0.09942    0.73333    bank loan banking rate central financial billion credit lending say
#  0.08925    0.88333    russia government russian country united yeltsin states minister union economic
#  0.13611    0.85000    art museum painting artist gallery building collection ms exhibition work
#  0.20389    0.95000    site internet web com www online mail information user http
#  0.04528    0.83333    city state water county area plant park building california mayor
#  0.04231    0.67000    peso sa percent mexico rise mexican company banco share fall
#  0.05186    0.85000    church catholic lewinsky file bishop priest starr bolivar enron ms
#
# Mean NPMI = 0.1246932
# Mean TU   = 0.832
